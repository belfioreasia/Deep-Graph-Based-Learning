# %% [markdown]
# # Question 3: Investigating Topology in Node-Based Classification Using GNNs
#
# In this section, we will explore the impact of graph topology on node-based classification using GNNs. The experiments will focus on analyzing different topological measures, visualizing their distributions, and evaluating GCN performance on 2 graphs with different topologies.

# %%
import json
import torch
import os
import random
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import networkx as nx
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
from graph_ricci_curvature import GraphRicciCurvature

import seaborn as sns

# %% [markdown]
# ## Helper function and code for loading data

# %%
G1_TRAIN_FILE_NAME = "q3_G1_train.json"
G1_EVAL_FILE_NAME = "q3_G1_eval.json"

G1_TRAIN_DATA_PATH = os.path.join("data",G1_TRAIN_FILE_NAME)
G1_EVAL_DATA_PATH = os.path.join("data",G1_EVAL_FILE_NAME)

G2_TRAIN_FILE_NAME = "q3_G2_train.json"
G2_EVAL_FILE_NAME = "q3_G2_eval.json"

G2_TRAIN_DATA_PATH = os.path.join("data",G2_TRAIN_FILE_NAME)
G2_EVAL_DATA_PATH = os.path.join("data",G2_EVAL_FILE_NAME)

# %%
# Functions to load the data
def create_Adj_matrix(N, edge_index):
    """Creates the adjacency matrix"""
    A = torch.zeros((N, N), dtype=torch.float)
    for idx, jdx in edge_index:
        A[idx, jdx] = 1
        A[jdx, idx] = 1
    return A

def read_json_data(file_path, has_label=True):
    with open(file_path, 'r') as f:
        data = json.load(f)
    
    if not type(data) == list:
        item = data
        X = torch.tensor(item['features'], dtype=torch.float)
        N = len(X)
        A = create_Adj_matrix(N, item['edge_index'])
        if has_label:
            y = torch.tensor(item['label'], dtype=torch.long)
        else:
            y = None
        return (X,A,y)

    graph_data = []
    for item in data:
        X = torch.tensor(item['features'], dtype=torch.float)
        N = len(X)
        A = create_Adj_matrix(N, item['edge_index'])
        if has_label:
            y = torch.tensor(item['label'], dtype=torch.long)
        else:
            y = None
        
        graph_data.append((X,A,y))
    
    return graph_data

# %% [markdown]
# ## Question 3.1 - Analyzing the Graphs

# %% [markdown]
# ### Q3.1.b Visualizing and Comparing Topological and Geometric Measures of Two Graphs
#
# Implement the following three functions to visualize and compare structural properties of two given graphs:
#
# - `plot_node_degree_distribution_two_graphs`
# - `plot_betweenness_centrality_distribution_two_graphs`
# - `plot_ollivier_ricci_curvature_distribution_two_graphs`

# %%
def compute_node_degree(A):
    """
    Given an adjacency matrix A of shape (N, N),
    return the degree (row sum) for each of the N nodes.
    """
    degrees = A.sum(dim=1)  # sum across columns
    return degrees

# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  


def plot_node_degree_distribution_two_graphs(A1, A2, dataset_name='Training', save=False, plot_name=""):
    """
    Plots the node degree distributions of two graphs
    with adjacency matrices A1 and A2 (each of shape (N, N))
    in a single figure.
    
    """
    plt.figure(figsize=(15, 15))
    node_deg_dist_G1 = compute_node_degree(A1)
    node_deg_dist_G2 = compute_node_degree(A2)

    # ensure all bins have equal width
    G1_bins = np.unique(node_deg_dist_G1)
    G2_bins = np.unique(node_deg_dist_G2)
    
    fig, ax = plt.subplots(figsize=(12, 6))
    plt.hist(x=node_deg_dist_G1, color="cornflowerblue", label="Graph 1", edgecolor='navy', alpha=0.6, bins=G1_bins)
    plt.hist(x=node_deg_dist_G2, color="orchid", label="Graph 2", edgecolor='purple', alpha=0.6, bins=G2_bins)

    plt.grid(True, alpha=0.5)

    plt.xlabel('Degree')
    plt.ylabel('Node Count')
    plt.title(f'Comparison of Node Degree Distributions\n{dataset_name} Dataset')
    plt.legend()
    if save:
        fig_name = f"images/Q3/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def compute_betweenness_centrality(A):
    """
    Calculate the betweenness centrality of each node in the graph
    defined by the given adjacency matrix A.
    """
    G = nx.from_numpy_array(A.numpy())
    betweenness_centrality = nx.betweenness_centrality(G)
    betweenness_centrality = np.array(list(betweenness_centrality.values()))
    return betweenness_centrality

def plot_betweenness_distribution_two_graphs(A1, A2, dataset_name='Training', save=False, plot_name=""):
    """
    Plots the betweenness centrality distributions of two graphs
    defined by adjacency matrices A1 and A2 (each of shape (N, N)) 
    in a single figure.
    """
    plt.figure(figsize=(15, 15))
    betweenness_G1 = compute_betweenness_centrality(A1)
    betweenness_G2 = compute_betweenness_centrality(A2)
    
    fig, ax = plt.subplots(figsize=(12, 6))
    plt.hist(x=betweenness_G1, color="cornflowerblue", label="Graph 1", edgecolor='navy', alpha=0.6)
    plt.hist(x=betweenness_G2, color="orchid", label="Graph 2", edgecolor='purple', alpha=0.6)

    plt.grid(True, alpha=0.5)

    plt.xlabel('Betweenness Centrality')
    plt.ylabel('Node Count')
    plt.title(f'Comparison of Betweenness Centrality Distributions\n{dataset_name} Dataset')
    plt.legend()
    if save:
        fig_name = f"images/Q3/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def plot_ricci_curvature_distribution_two_graphs(A1, A2, dataset_name='Training', save=False, plot_name=""):
    """
    Plots the Ollivier-Ricci curvature distributions for two graphs
    defined by adjacency matrices A1 and A2 (PyTorch tensors).
    
    Parameters
    ----------
    A1, A2 : torch.Tensor
        Adjacency matrices for two undirected graphs (NxN).
    """
    # 1) Convert PyTorch adjacency -> NumPy -> NetworkX Graph
    A1_np = A1.numpy()
    A2_np = A2.numpy()

    G1 = nx.from_numpy_array(A1_np)
    G2 = nx.from_numpy_array(A2_np)

    # 2) Instantiate OllivierRicci object for each graph
    ricci_calculator_G1 = GraphRicciCurvature(G1)
    ricci_calculator_G2 = GraphRicciCurvature(G2)

    # 3) Compute the Ricci curvature
    curvatures1 = ricci_calculator_G1.compute_ricci_curvatures()
    curvatures2 = ricci_calculator_G2.compute_ricci_curvatures()

    # After computation, the Ricci curvature for each edge is stored in G[u][v]["ricciCurvature"]

    # 4) Gather edge-level Ricci curvature values
    ricci_values_G1 = []
    for (u, v), val in curvatures1.items():
        ricci_values_G1.append(val)

    ricci_values_G2 = []
    for (u, v), val in curvatures2.items():
        ricci_values_G2.append(val)

    # Continue with plotting ...

    plt.figure(figsize=(15, 15))
    fig, ax = plt.subplots(figsize=(12, 6))
    plt.hist(x=ricci_values_G1, color="cornflowerblue", label="Graph 1", edgecolor='navy', alpha=0.6)
    plt.hist(x=ricci_values_G2, color="orchid", label="Graph 2", edgecolor='purple', alpha=0.6)

    plt.grid(True, alpha=0.5)

    plt.xlabel('Ricci Curvature')
    plt.ylabel('Edge Count')
    plt.title(f'Comparison of Oliver-Ricci Curvature\n{dataset_name} Dataset')
    plt.legend()
    if save:
        fig_name = f"images/Q3/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# %%
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

# %%
plot_node_degree_distribution_two_graphs(G1_train[1], G2_train[1], dataset_name='Training', save=True, plot_name="node_deg_dist_training")
plot_node_degree_distribution_two_graphs(G1_eval[1], G2_eval[1], dataset_name='Validation', save=True, plot_name="node_deg_dist_eval")

# %%
plot_betweenness_distribution_two_graphs(G1_train[1], G2_train[1], dataset_name='Training', save=True, plot_name="betweenness_training")
plot_betweenness_distribution_two_graphs(G1_eval[1], G2_eval[1], dataset_name='Validation', save=True, plot_name="betweenness_eval")

# %%
plot_ricci_curvature_distribution_two_graphs(G1_train[1], G2_train[1], dataset_name='Training', save=True, plot_name="ricci_curvature_training")
plot_ricci_curvature_distribution_two_graphs(G1_eval[1], G2_eval[1], dataset_name='Validation', save=True, plot_name="ricci_curvature_eval")

# %% [markdown]
# ### Q3.1.c Visualizing the Graphs
#
# Implement the `plot_graph` function to generate visual representations of both graphs. Ensure that the plots are clear and well-formatted.

# %%
def plot_graph(A, nodecolor='cornflowerblue', graph_name='G', save=False, plot_name=""):
    """
    Plots a graph defined by adjacency matrix A.
    Parameters
    ----------
    A : torch.Tensor
        Adjacency matrix of shape (N, N).
    """
    plt.figure(figsize=(15, 15))
    G = nx.from_numpy_array(A.numpy())
    pos = nx.spring_layout(G, seed=0)

    nx.draw_networkx_nodes(G, pos,
                            node_color=nodecolor,
                            node_size=300,
                            linewidths=3)
    nx.draw_networkx_edges(G, pos, edge_color='gray')
    nx.draw_networkx_labels(G, pos, 
                            font_size=10,
                            clip_on=True)
    plt.title(f"Graph {graph_name}")
    plt.grid(False)
    if save:
        fig_name = f"images/Q3/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# %%
plot_graph(G1_train[1], nodecolor='cornflowerblue', graph_name='Training G1', save=True, plot_name="Training_Graph_G1")
plot_graph(G1_eval[1], nodecolor='cornflowerblue', graph_name='Eval G1', save=True, plot_name="Eval_Graph_G1")

# %%
plot_graph(G2_train[1], nodecolor='orchid', graph_name='Training G2', save=True, plot_name="Training_Graph_G2")
plot_graph(G2_eval[1], nodecolor='orchid', graph_name='Eval G2', save=True, plot_name="Eval_Graph_G2")

# %% [markdown]
# ### Q3.1.d Visualizing Node Feature Distributions
#
# - Implement the function `plot_node_feature_dist_by_class_two_graphs` to visualize the average node feature distribution per class for two given graphs.
#
# - Do not consider the distribution of a specific feature $ x_i $, consider the mean of the feature vector $ \mathbf{x} $ for each node.
#
# - The function should generate a plot similar to Figure 3 in the Coursework Desciription PDF.

# %%
# HELPER FUNCTION ADAPTED FROM Q2
def get_avg_node_features(X, y):
    """
    Get the average feature values for each node class.
    Params:
        - X (torch.Tensor): Graph Nodes
        - y (torch.Tensor): Node labels (0 or 1 for all nodes in the graph)
    Returns:
        - class0_features (np.array): average feature values for nodes with class 0
        - class1_features (np.array): average feature values for nodes with class 1
    """
    class0_features = []
    class1_features = []
    for node_index, node in enumerate(X):
        if y[node_index] == 0:
            class0_features.append(torch.mean(node))
        else:
            class1_features.append(torch.mean(node))    
    return class0_features, class1_features

def plot_node_feature_dist_by_class_two_graphs(X_G1, X_G2, y_G1, y_G2, dataset_name='Training', save=False, plot_name=""):
    """
    Plots the distribution of the average node features by class for two graphs.
    """
    class0_features_G1, class1_features_G1 = get_avg_node_features(X_G1, y_G1)
    class0_features_G2, class1_features_G2 = get_avg_node_features(X_G2, y_G2)
    
    # Convert to numpy arrays and get the first feature dimension
    fig, axes = plt.subplots(figsize=(20, 8), ncols=2, nrows=1)

    # Plot for Graph 1
    axes[0].grid(True)
    
    axes[0].hist(x=class0_features_G1, color="cornflowerblue", label="Class 0", alpha=0.6, edgecolor='navy')
    axes[0].hist(x=class1_features_G1, color="orchid", label="Class 1", alpha=0.6, edgecolor='purple')
    axes[0].set_title('Graph 1: Avg Feature Distribution by Class')

    axes[0].set_xlabel('Average Feature Value')
    axes[0].set_ylabel('Frequency')
    axes[0].legend()

    # Plot for Graph 2
    axes[1].grid(True)

    axes[1].hist(x=class0_features_G2, color="cornflowerblue", label="Class 0", alpha=0.6, edgecolor='navy')
    axes[1].hist(x=class1_features_G2, color="orchid", label="Class 1", alpha=0.6, edgecolor='purple')
    axes[1].set_title('Graph 2: Avg Feature Distribution by Class')

    axes[1].set_xlabel('Average Feature Value')
    axes[1].set_ylabel('Frequency')
    axes[1].legend()

    fig.suptitle(f'Comparison of Average Node Feature Distributions by Class\n{dataset_name} Dataset')
    
    if save:
        fig_name = f"images/Q3/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# %%
plot_node_feature_dist_by_class_two_graphs(G1_train[0], G2_train[0], G1_train[2], G2_train[2], dataset_name='Training', save=True, plot_name="feature_dist_by_graph_training")
plot_node_feature_dist_by_class_two_graphs(G1_eval[0], G2_eval[0], G1_eval[2], G2_eval[2], dataset_name='Validation', save=True, plot_name="feature_dist_by_graph_eval")

# %% [markdown]
# ## Question 3.2 -  Evaluating GCN Performance on Different Graph Structures

# %% [markdown]
# ### Helper functions for normalising the A matrix.

# %%
# Helper function to normalise the A matrix
def symmetric_normalize(A_tilde):
    """
    Performs symmetric normalization of A_tilde (Adj. matrix with self loops):
      A_norm = D^{-1/2} * A_tilde * D^{-1/2}
    Where D_{ii} = sum of row i in A_tilde.

    A_tilde (N, N): Adj. matrix with self loops
    Returns:
      A_norm : (N, N)
    """

    eps = 1e-5
    d = A_tilde.sum(dim=1) + eps
    D_inv = torch.diag(torch.pow(d, -0.5))
    return D_inv @ A_tilde @ D_inv


def patch_A_matrix(A):
    """Patches the A matrix"""
    A = A + torch.eye(A.size(0))
    A = symmetric_normalize(A)
    return A

def patch_A_for_dataset(dataset):
    """Patches the A matrix for a dataset (list)"""
    dataset = [ (X, patch_A_matrix(A), y) for X,A,y in dataset]
    return dataset

# %% [markdown]
# ### Helper function for plotting training runs.

# %%
# Helper function for plotting:

def plot_training_and_validation(training_losses, validation_losses, graph1_label="Training Accuracy", graph2_label="Validation Accuracy", x_label="Epoch", title=None, save=False, plot_name=""):
    """
    Plots the validation accuracy and training loss over epochs.
    Args:
        validation_losses: List of validation accuracies (or losses)
        training_losses: List of training accuracies (or losses)
        aggregation: Aggregation method used (default: "mean")
    """
    plt.figure(figsize=(10, 6))
    
    # Create figure with two y-axes
    fig, ax1 = plt.subplots(figsize=(10, 6))
    ax2 = ax1.twinx()
    
    # Plot training loss on the first y-axis
    epochs = range(1, len(training_losses) + 1)
    line1 = ax1.plot(epochs, training_losses, 'orchid', label=f'{graph1_label}')
    ax1.set_xlabel(x_label)
    ax1.set_ylabel(f'{graph1_label}', color='orchid')
    ax1.tick_params(axis='y', labelcolor='orchid')
    
    # Plot validation accuracy on the second y-axis
    line2 = ax2.plot(epochs, validation_losses, 'cornflowerblue', label=f'{graph2_label}')
    ax2.set_ylabel(f'{graph2_label}', color='cornflowerblue')
    ax2.tick_params(axis='y', labelcolor='cornflowerblue')
    
    # Add title and grid
    if not title:
        title = f'Training Accuracy and Validation Accuracy Over Time'
    plt.title(title)

    ax1.grid(True)
    
    # Add legend
    lines = line1 + line2
    labels = [l.get_label() for l in lines]
    ax1.legend(lines, labels, loc='upper right')
    
    plt.tight_layout()
    if save:
        fig_name = f"images/Q1/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# %% [markdown]
# ### Provided GCN Code

# %%
#Provided GCN Implementation
class GCNLayer(nn.Module):
    """
    A single layer of a Graph Convolutional Network (GCN).
    """
    def __init__(self, input_dim, output_dim, use_nonlinearity=True):
        super(GCNLayer, self).__init__()
        self.use_nonlinearity = use_nonlinearity
        self.Omega = nn.Parameter(torch.randn(input_dim, output_dim) * torch.sqrt(torch.tensor(2.0) / (input_dim + output_dim)))
        self.beta = nn.Parameter(torch.zeros(output_dim))

    def forward(self, H_k, A_normalized):
        agg = torch.matmul(A_normalized, H_k) # local agg
        H_k_next = torch.matmul(agg, self.Omega) + self.beta
        return F.relu(H_k_next) if self.use_nonlinearity else H_k_next

class GraphNeuralNetwork(nn.Module):
    """
    A simple Graph Neural Network model using two layers of Graph Convolutional Network (GCN)
    for binary classification. The sigmoid activation is applied in the output layer only if
    use_nonlinearity is set to True.
    """
    def __init__(self, input_dim, hidden_dim):
        super(GraphNeuralNetwork, self).__init__()

        # Define GCN layers
        self.gcn1 = GCNLayer(input_dim, hidden_dim, True)
        self.gcn2 = GCNLayer(hidden_dim, 1, False)

    def forward(self, A, X, **kwargs):
        # Pass through GCN layers
        H1 = self.gcn1(X, A)
        H2 = self.gcn2(H1, A)  # Output shape: (num_nodes, 1)

        output = torch.sigmoid(H2)  # Sigmoid activation per node
        if torch.isnan(output).any():
            output = torch.where(torch.isnan(output), torch.zeros_like(output), output)

        if kwargs.get("return_embeddings", None):
            return output, (H1, H2)
        else:
            return output

# %% [markdown]
# ### Helper functions for training GCN on a graph

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torch.nn.functional import binary_cross_entropy
from sklearn.metrics import accuracy_score, classification_report,precision_recall_fscore_support

def train_model(
    model,
    G_train,
    G_val,
    num_epochs=10,
    lr=0.0001,
    verbose=True,
    **kwargs,
):
    """
    Train the model, validate every 'validate_every' epochs, and pick the 
    checkpoint with best validation accuracy.

    Parameters:
    -----------
    model : torch.nn.Module
        The PyTorch model to train.
    G_train  = (X_train,A_train,y_train) : input
        the Graph 1
    Y_train = (X_val,A_val,y_val)
        the Graph 2
    num_epochs : int
        Number of training epochs.
    lr : float
        Learning rate for the optimizer.
    verbose: bool
        whether to display the loss, f1 and val_f1


    Returns:
    --------
    loss_history : list
        The training loss history across epochs.
    f1_train_history : list
        train F1s during training
    f1_val_history : list
        val F1s during training
    """
    X_train, A_train, y_train = G_train
    X_val, A_val, y_val = G_val

    model.train()
    optimizer = optim.AdamW(model.parameters(), lr=lr)
    loss_history = []
    train_f1_history = []
    validation_f1_history = []

    for epoch in range(num_epochs):
        # A single Epoch training.
        # TRAINING
        model.train()
        optimizer.zero_grad()
        if kwargs.get("return_embeddings", None):
            out, embeddings = model(A_train, X_train, **kwargs)
        else:
            out = model(A_train, X_train, **kwargs)
        out = out.squeeze(-1)  # shape: (N,) if needed
        y_float = y_train.float()  # for BCE

        # Compute training loss
        loss = binary_cross_entropy(out, y_float)
        loss.backward()

        # torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        # Record training loss
        loss_value = loss.item()
        
        # EVALUATION
        loss_history.append(loss_value)
        train_prec, train_rec, train_f1, _ = evaluate_model(model, X_train, A_train, y_train)
        val_prec, val_rec, val_f1, _ = evaluate_model(model,  X_val, A_val, y_val)

        train_f1_history.append(train_f1)
        validation_f1_history.append(val_f1)                     
        # Evaluating the model
        if verbose:
            print(f"Epoch {epoch+1}, Training Loss: {loss_value}, Train F1: {train_f1:.4f}, Validation F1: {val_f1:.4f}")
            
    if kwargs.get("return_embeddings", None):
        return loss_history, train_f1_history, validation_f1_history, embeddings
    else:
        return loss_history, train_f1_history, validation_f1_history


@torch.no_grad()
def evaluate_model(model, X,A,y, **kwargs):
    """
    Runs forward pass, calculates binary predictions (threshold=0.5),
    and returns the accuracy score.
    """
    model.eval()
    if kwargs.get("return_embeddings", None):
        out,_ = model(A,X,**kwargs)  # shape: (N, 1)
    else:
        out = model(A,X,**kwargs)  # shape: (N, 1)
    out = out.squeeze(-1)  # shape: (N,)
    preds = (out >= 0.5).long()

    y_true = y.cpu().numpy()
    y_pred = preds.cpu().numpy()

    return precision_recall_fscore_support(y_true, y_pred, average="micro")

# %% [markdown]
# ### Q3.2.a - Implementation of Layered GCN
#
#
# • Implement a GCN where layers can be passed as input parameter and that can return all
# embedding layers. (If you will not be able to do so, to get results implement one class per
# layer).
#
# • Train the GCN on G1 and G2 independently. Plot your results. (Note: you don’t need to
# get a high performance at this stage, just make sure it trains).

# %%
# SOLUTION Q3.2.a
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

class GCNLayer(nn.Module):
    """
    A single layer of a Graph Convolutional Network (GCN).
    """
    def __init__(self, input_dim, output_dim, use_nonlinearity=True):
        super(GCNLayer, self).__init__()
        self.use_nonlinearity = use_nonlinearity
        self.Omega = nn.Parameter(torch.randn(input_dim, output_dim) * torch.sqrt(torch.tensor(2.0) / (input_dim + output_dim)))
        self.beta = nn.Parameter(torch.zeros(output_dim))

    def forward(self, H_k, A_normalized):
        agg = torch.matmul(A_normalized, H_k) # local agg
        H_k_next = torch.matmul(agg, self.Omega) + self.beta
        return F.relu(H_k_next) if self.use_nonlinearity else H_k_next

# Adapted GCN Implementation
class LayeredGraphNeuralNetwork(nn.Module):
    """
    A simple Graph Neural Network model using two layers of Graph Convolutional Network (GCN)
    for binary classification. The sigmoid activation is applied in the output layer only if
    use_nonlinearity is set to True.
    """
    def __init__(self, input_dim, hidden_dim, layers_num):
        super(LayeredGraphNeuralNetwork, self).__init__()   
        # Define GCN layers
        self.layers = nn.ModuleList()
        in_dim = input_dim
        out_dim = hidden_dim
        for i in range(layers_num-1):
            self.layers.append(GCNLayer(in_dim, out_dim, True))
            in_dim = hidden_dim
        self.layers.append(GCNLayer(in_dim, 1, False))


    def forward(self, A, X, **kwargs):
        # Apply self-connections and normalize adjacency matrix
        A = A + torch.eye(A.size(0)) # to get A_tilde
        A_normalized = symmetric_normalize(A)
        # Pass through all GCN layers
        H_k = X
        graph_embeddings = []
        for layer in self.layers:
            H_k = layer(H_k, A_normalized)
            graph_embeddings.append(H_k)

        graph_output = torch.sigmoid(H_k)

        if torch.isnan(graph_output).any():
            graph_output = torch.where(torch.isnan(graph_output), torch.zeros_like(graph_output), graph_output)

        if kwargs.get("return_embeddings", None):
            return graph_output, graph_embeddings
        else:
            return graph_output

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Code to run the training and evaluation of the model with different number of layers.
#
# Adapt it as needed.

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

# Initialising the model
input_dim = 10
hidden_dim = 8
layers_num = 4
model = LayeredGraphNeuralNetwork(input_dim, hidden_dim, layers_num=layers_num) 
print(model)

losses, train_f1, val_f1, last_embeddings = train_model(
    model,
    G1_train,
    G1_eval,
    num_epochs=200,
    lr=0.0005,
    verbose=True,
    return_embeddings=True
)
plot_training_and_validation(losses, val_f1, graph1_label="Training Loss", graph2_label="Validation F1", x_label="Epoch", title="Training Loss and Validation F1 Over Time (G1 Graph)", save=False, plot_name="training_validation_f1")
plot_training_and_validation(train_f1, val_f1, graph1_label="Training F1", graph2_label="Validation F1", x_label="Epoch", title="Training and Validation F1 Over Time (G1 Graph)", save=False, plot_name="training_validation_f1")

print(len(last_embeddings))
# Out:
# LayeredGraphNeuralNetwork(
#   (layers): ModuleList(
#     (0-3): 4 x GCNLayer()
#   )
# )
# Epoch 1, Training Loss: 0.7310253381729126, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 2, Training Loss: 0.7295264601707458, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 3, Training Loss: 0.728045642375946, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 4, Training Loss: 0.7265936136245728, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 5, Training Loss: 0.7251775860786438, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 6, Training Loss: 0.7237876057624817, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 7, Training Loss: 0.7224196195602417, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 8, Training Loss: 0.7210641503334045, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 9, Training Loss: 0.7197276949882507, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 10, Training Loss: 0.7184144854545593, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 11, Training Loss: 0.7171242833137512, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 12, Training Loss: 0.7158516645431519, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 13, Training Loss: 0.7145992517471313, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 14, Training Loss: 0.7133703827857971, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 15, Training Loss: 0.7121679782867432, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 16, Training Loss: 0.7109858393669128, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 17, Training Loss: 0.7098190784454346, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 18, Training Loss: 0.7086706161499023, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 19, Training Loss: 0.7075456976890564, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 20, Training Loss: 0.706436038017273, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 21, Training Loss: 0.705339789390564, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 22, Training Loss: 0.7042620778083801, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 23, Training Loss: 0.7032018303871155, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 24, Training Loss: 0.7021546959877014, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 25, Training Loss: 0.701122522354126, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 26, Training Loss: 0.7001047730445862, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 27, Training Loss: 0.699101448059082, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 28, Training Loss: 0.6981096267700195, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 29, Training Loss: 0.697128415107727, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 30, Training Loss: 0.6961594820022583, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 31, Training Loss: 0.6952015161514282, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 32, Training Loss: 0.6942533254623413, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 33, Training Loss: 0.693318247795105, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 34, Training Loss: 0.6923970580101013, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 35, Training Loss: 0.6914848685264587, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 36, Training Loss: 0.6905896067619324, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 37, Training Loss: 0.6897047758102417, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 38, Training Loss: 0.6888272166252136, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 39, Training Loss: 0.687959611415863, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 40, Training Loss: 0.6870993375778198, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 41, Training Loss: 0.6862456798553467, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 42, Training Loss: 0.6853982210159302, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 43, Training Loss: 0.6845582723617554, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 44, Training Loss: 0.6837238073348999, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 45, Training Loss: 0.6828929781913757, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 46, Training Loss: 0.6820663809776306, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 47, Training Loss: 0.6812430024147034, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 48, Training Loss: 0.6804243326187134, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 49, Training Loss: 0.6796096563339233, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 50, Training Loss: 0.6787981986999512, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 51, Training Loss: 0.6779913306236267, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 52, Training Loss: 0.6771875619888306, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 53, Training Loss: 0.676384449005127, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 54, Training Loss: 0.675582230091095, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 55, Training Loss: 0.6747804880142212, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 56, Training Loss: 0.6739782094955444, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 57, Training Loss: 0.6731760501861572, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 58, Training Loss: 0.672374427318573, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 59, Training Loss: 0.6715726852416992, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 60, Training Loss: 0.6707699298858643, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 61, Training Loss: 0.669960618019104, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 62, Training Loss: 0.6691460609436035, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 63, Training Loss: 0.6683259606361389, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 64, Training Loss: 0.6675012111663818, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 65, Training Loss: 0.6666709184646606, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 66, Training Loss: 0.6658388376235962, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 67, Training Loss: 0.6650046110153198, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 68, Training Loss: 0.6641641855239868, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 69, Training Loss: 0.6633180379867554, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 70, Training Loss: 0.6624615788459778, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 71, Training Loss: 0.661604642868042, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 72, Training Loss: 0.6607449054718018, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 73, Training Loss: 0.659883439540863, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 74, Training Loss: 0.6590098142623901, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 75, Training Loss: 0.6581287980079651, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 76, Training Loss: 0.6572427153587341, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 77, Training Loss: 0.6563518643379211, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 78, Training Loss: 0.6554614305496216, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 79, Training Loss: 0.6545780897140503, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 80, Training Loss: 0.6536914706230164, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 81, Training Loss: 0.6527907252311707, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 82, Training Loss: 0.6518888473510742, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 83, Training Loss: 0.6509836316108704, Train F1: 0.4875, Validation F1: 0.5000
# Epoch 84, Training Loss: 0.6500781774520874, Train F1: 0.4875, Validation F1: 0.5000
# Epoch 85, Training Loss: 0.6491646766662598, Train F1: 0.4875, Validation F1: 0.5333
# Epoch 86, Training Loss: 0.6482241153717041, Train F1: 0.4875, Validation F1: 0.5667
# Epoch 87, Training Loss: 0.6472686529159546, Train F1: 0.4875, Validation F1: 0.5667
# Epoch 88, Training Loss: 0.6463087201118469, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 89, Training Loss: 0.6453242897987366, Train F1: 0.5125, Validation F1: 0.6000
# Epoch 90, Training Loss: 0.6443292498588562, Train F1: 0.5125, Validation F1: 0.6000
# Epoch 91, Training Loss: 0.6433272957801819, Train F1: 0.5125, Validation F1: 0.6000
# Epoch 92, Training Loss: 0.6423165202140808, Train F1: 0.5250, Validation F1: 0.6000
# Epoch 93, Training Loss: 0.6412960886955261, Train F1: 0.5250, Validation F1: 0.6000
# Epoch 94, Training Loss: 0.6402685046195984, Train F1: 0.5375, Validation F1: 0.6000
# Epoch 95, Training Loss: 0.6392294764518738, Train F1: 0.5500, Validation F1: 0.6000
# Epoch 96, Training Loss: 0.638178825378418, Train F1: 0.5875, Validation F1: 0.5667
# Epoch 97, Training Loss: 0.6371169090270996, Train F1: 0.6500, Validation F1: 0.5667
# Epoch 98, Training Loss: 0.6360429525375366, Train F1: 0.6500, Validation F1: 0.5667
# Epoch 99, Training Loss: 0.6349567174911499, Train F1: 0.6625, Validation F1: 0.5667
# Epoch 100, Training Loss: 0.633857786655426, Train F1: 0.6750, Validation F1: 0.6667
# Epoch 101, Training Loss: 0.6327403783798218, Train F1: 0.7000, Validation F1: 0.7000
# Epoch 102, Training Loss: 0.6316068172454834, Train F1: 0.7250, Validation F1: 0.7000
# Epoch 103, Training Loss: 0.630464494228363, Train F1: 0.7375, Validation F1: 0.7000
# Epoch 104, Training Loss: 0.6293398141860962, Train F1: 0.7375, Validation F1: 0.7333
# Epoch 105, Training Loss: 0.6282110214233398, Train F1: 0.7750, Validation F1: 0.7333
# Epoch 106, Training Loss: 0.6270716190338135, Train F1: 0.7750, Validation F1: 0.7333
# Epoch 107, Training Loss: 0.625931978225708, Train F1: 0.7750, Validation F1: 0.7333
# Epoch 108, Training Loss: 0.6247898936271667, Train F1: 0.8000, Validation F1: 0.7333
# Epoch 109, Training Loss: 0.6236446499824524, Train F1: 0.8000, Validation F1: 0.7333
# Epoch 110, Training Loss: 0.6225037574768066, Train F1: 0.8000, Validation F1: 0.7333
# Epoch 111, Training Loss: 0.6213616728782654, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 112, Training Loss: 0.62021803855896, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 113, Training Loss: 0.6190795302391052, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 114, Training Loss: 0.6179405450820923, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 115, Training Loss: 0.616808295249939, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 116, Training Loss: 0.6156719923019409, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 117, Training Loss: 0.6145362257957458, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 118, Training Loss: 0.6134136319160461, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 119, Training Loss: 0.6123048067092896, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 120, Training Loss: 0.6112033128738403, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 121, Training Loss: 0.610122561454773, Train F1: 0.8500, Validation F1: 0.8333
# Epoch 122, Training Loss: 0.6090565919876099, Train F1: 0.8500, Validation F1: 0.8333
# Epoch 123, Training Loss: 0.6080029606819153, Train F1: 0.8500, Validation F1: 0.8333
# Epoch 124, Training Loss: 0.6069599390029907, Train F1: 0.8500, Validation F1: 0.8333
# Epoch 125, Training Loss: 0.6059285402297974, Train F1: 0.8500, Validation F1: 0.8333
# Epoch 126, Training Loss: 0.6049311757087708, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 127, Training Loss: 0.6039507985115051, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 128, Training Loss: 0.6029831171035767, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 129, Training Loss: 0.6020289659500122, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 130, Training Loss: 0.6010874509811401, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 131, Training Loss: 0.6001555919647217, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 132, Training Loss: 0.5992324948310852, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 133, Training Loss: 0.5983402132987976, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 134, Training Loss: 0.5974674820899963, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 135, Training Loss: 0.5966119766235352, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 136, Training Loss: 0.5957721471786499, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 137, Training Loss: 0.594942033290863, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 138, Training Loss: 0.5941263437271118, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 139, Training Loss: 0.593325138092041, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 140, Training Loss: 0.5925461649894714, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 141, Training Loss: 0.5917867422103882, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 142, Training Loss: 0.5910431742668152, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 143, Training Loss: 0.5903164148330688, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 144, Training Loss: 0.5896108746528625, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 145, Training Loss: 0.5889196395874023, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 146, Training Loss: 0.5882450342178345, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 147, Training Loss: 0.5875852704048157, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 148, Training Loss: 0.5869391560554504, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 149, Training Loss: 0.5863088369369507, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 150, Training Loss: 0.5856937170028687, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 151, Training Loss: 0.585092306137085, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 152, Training Loss: 0.584504246711731, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 153, Training Loss: 0.583935022354126, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 154, Training Loss: 0.5833840370178223, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 155, Training Loss: 0.5828460454940796, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 156, Training Loss: 0.5823217630386353, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 157, Training Loss: 0.5818091034889221, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 158, Training Loss: 0.5813083052635193, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 159, Training Loss: 0.5808185338973999, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 160, Training Loss: 0.5803391337394714, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 161, Training Loss: 0.57986980676651, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 162, Training Loss: 0.5794109106063843, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 163, Training Loss: 0.5789623856544495, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 164, Training Loss: 0.5785233974456787, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 165, Training Loss: 0.5780925154685974, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 166, Training Loss: 0.5776715874671936, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 167, Training Loss: 0.577260434627533, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 168, Training Loss: 0.5768571496009827, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 169, Training Loss: 0.5764663815498352, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 170, Training Loss: 0.5760834813117981, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 171, Training Loss: 0.5757068991661072, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 172, Training Loss: 0.5753365755081177, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 173, Training Loss: 0.5749735832214355, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 174, Training Loss: 0.5746167898178101, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 175, Training Loss: 0.5742657780647278, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 176, Training Loss: 0.5739201903343201, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 177, Training Loss: 0.5735788941383362, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 178, Training Loss: 0.5732437372207642, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 179, Training Loss: 0.5729126930236816, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 180, Training Loss: 0.5725854635238647, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 181, Training Loss: 0.5722629427909851, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 182, Training Loss: 0.5719440579414368, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 183, Training Loss: 0.5716283321380615, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 184, Training Loss: 0.5713158845901489, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 185, Training Loss: 0.5710059404373169, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 186, Training Loss: 0.57069993019104, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 187, Training Loss: 0.5703970193862915, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 188, Training Loss: 0.5700980424880981, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 189, Training Loss: 0.5698021054267883, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 190, Training Loss: 0.5695090889930725, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 191, Training Loss: 0.5692180395126343, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 192, Training Loss: 0.5689290761947632, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 193, Training Loss: 0.568641185760498, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 194, Training Loss: 0.5683534741401672, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 195, Training Loss: 0.5680673122406006, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 196, Training Loss: 0.5677820444107056, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 197, Training Loss: 0.5674988031387329, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 198, Training Loss: 0.5672160387039185, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 199, Training Loss: 0.5669338703155518, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 200, Training Loss: 0.5666519403457642, Train F1: 0.8500, Validation F1: 0.7667
# 4

# %% [markdown]
# ### Q3.2.b - Plotting of t-SNE Embeddings for Graph Neural Networks
#
# • Use t-SNE to visualize the node embeddings for the final layer of the GCN for each graph
# for both training and evaluation data, use the labels as class labels for the tsne plot.

# %%
# SOLUTION Q3.5.b
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  
from sklearn.manifold import TSNE

def plot_tsne(embeddings, labels=None, layer_to_plot=-1, colors=['cornflowerblue', 'orchid'], save=False, plot_name=""):
    """
    embeddings (list):
        list of embeddings (layer 2, ..., layer N)
        NOTE: for num_layer = 1 there is no embedding (as it is just the input)
    
    labels (list):
        list of labels
    
    layer_to_plot (int):
        which layer to plot (default -1, i.e. the last layer)
    """
    emb_to_plot = embeddings[layer_to_plot].detach().numpy()
    embedding_tsne = TSNE(n_components=1, perplexity = 5).fit_transform(emb_to_plot)

    fig, ax = plt.subplots(figsize=(6, 6))
    x = np.arange(len(embedding_tsne))
    for node_class in np.unique(labels):
        label_node_idx = np.where(labels == node_class)
        ax.scatter(x[label_node_idx], embedding_tsne[label_node_idx], label=f'Class {node_class}', color=colors[node_class], alpha=0.7, s=150)
    ax.legend()

    title = f"TSNE plot of embeddings at layer {layer_to_plot+1}"
    if layer_to_plot == -1 or layer_to_plot == len(embeddings)-1:
        title += ' (last layer)'
    ax.set_title(title)
    if save:
        fig_name = f"images/Q3/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Plotting the t-SNE embeddings
#
# Adapt as needed.

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

# Initialising the model
input_dim = 10
hidden_dim = 8
layers_num = 4
model = LayeredGraphNeuralNetwork(input_dim, hidden_dim, layers_num=layers_num)
print("Created model with pre-defined Layers")
print(model)

# Train on G1
print("Training on G1")
losses, train_f1, val_f1, last_embeddings = train_model(
    model,
    G1_train,
    G1_eval,
    num_epochs=200,
    lr=0.0005,
    verbose=True,
    return_embeddings=True # NOTE we added this parameter
)
plot_training_and_validation(losses, val_f1, graph1_label="Training Loss", graph2_label="Validation F1", x_label="Epoch", title="Training Loss and Validation F1 Over Time (G1 Graph)", save=False, plot_name="training_validation_f1")
plot_training_and_validation(train_f1, val_f1, graph1_label="Training F1", graph2_label="Validation F1", x_label="Epoch", title="Training and Validation F1 Over Time (G1 Graph)", save=False, plot_name="training_validation_f1")

# print(len(last_embeddings))
plot_tsne(last_embeddings, G1_train[2], save=False, plot_name=f"tSNE_layer_{str(len(last_embeddings))}")

# Train on G2
print("\nTraining on G2")
losses, train_f1, val_f1, last_embeddings = train_model(
    model,
    G2_train,
    G2_eval,
    num_epochs=200,
    lr=0.0005,
    verbose=True,
    return_embeddings=True # NOTE we added this parameter
)
plot_training_and_validation(losses, val_f1, graph1_label="Training Loss", graph2_label="Validation F1", x_label="Epoch", title="Training Loss and Validation F1 Over Time (G2 Graph)", save=False, plot_name="training_validation_f1")
plot_training_and_validation(train_f1, val_f1, graph1_label="Training F1", graph2_label="Validation F1", x_label="Epoch", title="Training and Validation F1 Over Time (G2 Graph)", save=False, plot_name="training_validation_f1")

# print(len(last_embeddings))
plot_tsne(last_embeddings, G1_train[2], save=False, plot_name=f"tSNE_layer_{str(len(last_embeddings))}")
# Out:
# Created model with pre-defined Layers
# LayeredGraphNeuralNetwork(
#   (layers): ModuleList(
#     (0-3): 4 x GCNLayer()
#   )
# )
# Training on G1
# Epoch 1, Training Loss: 0.7271090745925903, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 2, Training Loss: 0.7255311012268066, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 3, Training Loss: 0.72397381067276, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 4, Training Loss: 0.7224348783493042, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 5, Training Loss: 0.720916748046875, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 6, Training Loss: 0.7194227576255798, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 7, Training Loss: 0.7179520726203918, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 8, Training Loss: 0.7165347337722778, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 9, Training Loss: 0.7151578664779663, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 10, Training Loss: 0.7137914299964905, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 11, Training Loss: 0.7124279141426086, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 12, Training Loss: 0.7110655903816223, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 13, Training Loss: 0.7097020745277405, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 14, Training Loss: 0.7083466649055481, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 15, Training Loss: 0.7069951295852661, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 16, Training Loss: 0.705650806427002, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 17, Training Loss: 0.7043237686157227, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 18, Training Loss: 0.7030055522918701, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 19, Training Loss: 0.7017122507095337, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 20, Training Loss: 0.7004362940788269, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 21, Training Loss: 0.699167788028717, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 22, Training Loss: 0.6979091167449951, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 23, Training Loss: 0.6966578960418701, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 24, Training Loss: 0.6954063773155212, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 25, Training Loss: 0.6941530108451843, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 26, Training Loss: 0.6929137706756592, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 27, Training Loss: 0.6916812658309937, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 28, Training Loss: 0.6904500126838684, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 29, Training Loss: 0.6892195343971252, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 30, Training Loss: 0.6879945993423462, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 31, Training Loss: 0.6867815852165222, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 32, Training Loss: 0.6855765581130981, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 33, Training Loss: 0.6843531727790833, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 34, Training Loss: 0.6831293702125549, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 35, Training Loss: 0.6819000840187073, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 36, Training Loss: 0.6806681752204895, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 37, Training Loss: 0.679437518119812, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 38, Training Loss: 0.6782028079032898, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 39, Training Loss: 0.6769493818283081, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 40, Training Loss: 0.6756871342658997, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 41, Training Loss: 0.6744248867034912, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 42, Training Loss: 0.6731642484664917, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 43, Training Loss: 0.6719045639038086, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 44, Training Loss: 0.6706430315971375, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 45, Training Loss: 0.6693822741508484, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 46, Training Loss: 0.6681218147277832, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 47, Training Loss: 0.6668626666069031, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 48, Training Loss: 0.6655949354171753, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 49, Training Loss: 0.6643258929252625, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 50, Training Loss: 0.6630563139915466, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 51, Training Loss: 0.661784291267395, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 52, Training Loss: 0.6605104804039001, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 53, Training Loss: 0.659231424331665, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 54, Training Loss: 0.6579452157020569, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 55, Training Loss: 0.6566544771194458, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 56, Training Loss: 0.6553581953048706, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 57, Training Loss: 0.6540604829788208, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 58, Training Loss: 0.6527630090713501, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 59, Training Loss: 0.6514599323272705, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 60, Training Loss: 0.6501501798629761, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 61, Training Loss: 0.6488367319107056, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 62, Training Loss: 0.647520124912262, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 63, Training Loss: 0.6462003588676453, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 64, Training Loss: 0.6448783874511719, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 65, Training Loss: 0.6435524225234985, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 66, Training Loss: 0.6422204971313477, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 67, Training Loss: 0.6408765912055969, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 68, Training Loss: 0.6395580768585205, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 69, Training Loss: 0.6382487416267395, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 70, Training Loss: 0.6369379758834839, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 71, Training Loss: 0.6356402635574341, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 72, Training Loss: 0.634353756904602, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 73, Training Loss: 0.6330761313438416, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 74, Training Loss: 0.6317994594573975, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 75, Training Loss: 0.6305288672447205, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 76, Training Loss: 0.6292632818222046, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 77, Training Loss: 0.6280041933059692, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 78, Training Loss: 0.6267496943473816, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 79, Training Loss: 0.6254987716674805, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 80, Training Loss: 0.6242591142654419, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 81, Training Loss: 0.6230289340019226, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 82, Training Loss: 0.621782660484314, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 83, Training Loss: 0.6205303072929382, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 84, Training Loss: 0.6192736029624939, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 85, Training Loss: 0.6180161237716675, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 86, Training Loss: 0.6167619228363037, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 87, Training Loss: 0.6155102252960205, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 88, Training Loss: 0.6142559051513672, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 89, Training Loss: 0.6129992604255676, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 90, Training Loss: 0.6117403507232666, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 91, Training Loss: 0.6104814410209656, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 92, Training Loss: 0.6092271208763123, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 93, Training Loss: 0.6079712510108948, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 94, Training Loss: 0.6067141890525818, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 95, Training Loss: 0.6054617166519165, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 96, Training Loss: 0.6042054295539856, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 97, Training Loss: 0.6029422283172607, Train F1: 0.5625, Validation F1: 0.5000
# Epoch 98, Training Loss: 0.6016807556152344, Train F1: 0.5875, Validation F1: 0.4667
# Epoch 99, Training Loss: 0.6004177331924438, Train F1: 0.6125, Validation F1: 0.5000
# Epoch 100, Training Loss: 0.5991533398628235, Train F1: 0.6500, Validation F1: 0.5000
# Epoch 101, Training Loss: 0.5978845953941345, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 102, Training Loss: 0.5966079831123352, Train F1: 0.6875, Validation F1: 0.5333
# Epoch 103, Training Loss: 0.5953294038772583, Train F1: 0.7125, Validation F1: 0.5333
# Epoch 104, Training Loss: 0.5940531492233276, Train F1: 0.7625, Validation F1: 0.5667
# Epoch 105, Training Loss: 0.592777669429779, Train F1: 0.7750, Validation F1: 0.5667
# Epoch 106, Training Loss: 0.5915042161941528, Train F1: 0.7750, Validation F1: 0.6000
# Epoch 107, Training Loss: 0.5902299284934998, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 108, Training Loss: 0.5889549851417542, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 109, Training Loss: 0.5876801013946533, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 110, Training Loss: 0.5864049196243286, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 111, Training Loss: 0.5851305723190308, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 112, Training Loss: 0.5838568806648254, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 113, Training Loss: 0.5825836658477783, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 114, Training Loss: 0.5813107490539551, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 115, Training Loss: 0.5800422430038452, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 116, Training Loss: 0.5787814259529114, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 117, Training Loss: 0.5775226354598999, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 118, Training Loss: 0.5762665271759033, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 119, Training Loss: 0.575018584728241, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 120, Training Loss: 0.5737766623497009, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 121, Training Loss: 0.5725396871566772, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 122, Training Loss: 0.5713087916374207, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 123, Training Loss: 0.5700801610946655, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 124, Training Loss: 0.5688539147377014, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 125, Training Loss: 0.5676302313804626, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 126, Training Loss: 0.5664093494415283, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 127, Training Loss: 0.5651938319206238, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 128, Training Loss: 0.5639849901199341, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 129, Training Loss: 0.5627838373184204, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 130, Training Loss: 0.5615876913070679, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 131, Training Loss: 0.5603960752487183, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 132, Training Loss: 0.5592097043991089, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 133, Training Loss: 0.5580289363861084, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 134, Training Loss: 0.5568545460700989, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 135, Training Loss: 0.5556860566139221, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 136, Training Loss: 0.5545216798782349, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 137, Training Loss: 0.5533621907234192, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 138, Training Loss: 0.5522081255912781, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 139, Training Loss: 0.5510584712028503, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 140, Training Loss: 0.5499135255813599, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 141, Training Loss: 0.5487738251686096, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 142, Training Loss: 0.5476420521736145, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 143, Training Loss: 0.5465167760848999, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 144, Training Loss: 0.5453969240188599, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 145, Training Loss: 0.5442830324172974, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 146, Training Loss: 0.5431761741638184, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 147, Training Loss: 0.542077898979187, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 148, Training Loss: 0.5409860014915466, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 149, Training Loss: 0.5398995876312256, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 150, Training Loss: 0.5388199687004089, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 151, Training Loss: 0.5377473831176758, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 152, Training Loss: 0.5366817712783813, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 153, Training Loss: 0.5356243848800659, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 154, Training Loss: 0.5345779657363892, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 155, Training Loss: 0.5335382223129272, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 156, Training Loss: 0.5325053930282593, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 157, Training Loss: 0.5314817428588867, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 158, Training Loss: 0.53046715259552, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 159, Training Loss: 0.5294610261917114, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 160, Training Loss: 0.528461754322052, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 161, Training Loss: 0.5274694561958313, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 162, Training Loss: 0.5264895558357239, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 163, Training Loss: 0.5255219340324402, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 164, Training Loss: 0.5245758295059204, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 165, Training Loss: 0.5236417055130005, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 166, Training Loss: 0.5227165222167969, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 167, Training Loss: 0.5218063592910767, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 168, Training Loss: 0.5209091901779175, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 169, Training Loss: 0.5200271606445312, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 170, Training Loss: 0.5191623568534851, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 171, Training Loss: 0.518326461315155, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 172, Training Loss: 0.5175105929374695, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 173, Training Loss: 0.5167040228843689, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 174, Training Loss: 0.515906572341919, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 175, Training Loss: 0.51512211561203, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 176, Training Loss: 0.5143520832061768, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 177, Training Loss: 0.5135886669158936, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 178, Training Loss: 0.5128386616706848, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 179, Training Loss: 0.5120971202850342, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 180, Training Loss: 0.5113652944564819, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 181, Training Loss: 0.5106432437896729, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 182, Training Loss: 0.5099352598190308, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 183, Training Loss: 0.5092374086380005, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 184, Training Loss: 0.5085495710372925, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 185, Training Loss: 0.5078712105751038, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 186, Training Loss: 0.5072020888328552, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 187, Training Loss: 0.5065408945083618, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 188, Training Loss: 0.5058876872062683, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 189, Training Loss: 0.5052427053451538, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 190, Training Loss: 0.5046058893203735, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 191, Training Loss: 0.5039772987365723, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 192, Training Loss: 0.5033571124076843, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 193, Training Loss: 0.502745509147644, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 194, Training Loss: 0.5021419525146484, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 195, Training Loss: 0.5015470385551453, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 196, Training Loss: 0.5009600520133972, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 197, Training Loss: 0.5003806948661804, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 198, Training Loss: 0.49980872869491577, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 199, Training Loss: 0.4992438852787018, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 200, Training Loss: 0.49868589639663696, Train F1: 0.8250, Validation F1: 0.7000
# Training on G2
# Epoch 1, Training Loss: 0.8613815307617188, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 2, Training Loss: 0.8587926030158997, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 3, Training Loss: 0.8562402725219727, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 4, Training Loss: 0.8537248373031616, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 5, Training Loss: 0.8512466549873352, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 6, Training Loss: 0.8488057851791382, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 7, Training Loss: 0.8464027643203735, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 8, Training Loss: 0.8440375328063965, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 9, Training Loss: 0.8417102694511414, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 10, Training Loss: 0.8394211530685425, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 11, Training Loss: 0.8371701240539551, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 12, Training Loss: 0.8349573016166687, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 13, Training Loss: 0.8327827453613281, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 14, Training Loss: 0.8306460380554199, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 15, Training Loss: 0.8285471796989441, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 16, Training Loss: 0.8264861106872559, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 17, Training Loss: 0.8244624137878418, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 18, Training Loss: 0.8224760293960571, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 19, Training Loss: 0.8205267190933228, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 20, Training Loss: 0.8186138272285461, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 21, Training Loss: 0.8167370557785034, Train F1: 0.3875, Validation F1: 0.6333
# Epoch 22, Training Loss: 0.814896285533905, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 23, Training Loss: 0.8130906820297241, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 24, Training Loss: 0.8113200068473816, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 25, Training Loss: 0.8095839619636536, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 26, Training Loss: 0.8078815340995789, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 27, Training Loss: 0.8062126040458679, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 28, Training Loss: 0.80457603931427, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 29, Training Loss: 0.8029691576957703, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 30, Training Loss: 0.8013873100280762, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 31, Training Loss: 0.7998250722885132, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 32, Training Loss: 0.7982787489891052, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 33, Training Loss: 0.7967380285263062, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 34, Training Loss: 0.7952061891555786, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 35, Training Loss: 0.7936885952949524, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 36, Training Loss: 0.792188286781311, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 37, Training Loss: 0.7907098531723022, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 38, Training Loss: 0.789254367351532, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 39, Training Loss: 0.7878223657608032, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 40, Training Loss: 0.7864146828651428, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 41, Training Loss: 0.7850318551063538, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 42, Training Loss: 0.7836743593215942, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 43, Training Loss: 0.7823441624641418, Train F1: 0.3125, Validation F1: 0.6333
# Epoch 44, Training Loss: 0.7810514569282532, Train F1: 0.3125, Validation F1: 0.4333
# Epoch 45, Training Loss: 0.7798166275024414, Train F1: 0.3125, Validation F1: 0.3000
# Epoch 46, Training Loss: 0.7786462903022766, Train F1: 0.3125, Validation F1: 0.2667
# Epoch 47, Training Loss: 0.7775209546089172, Train F1: 0.3125, Validation F1: 0.2667
# Epoch 48, Training Loss: 0.7764187455177307, Train F1: 0.3125, Validation F1: 0.2667
# Epoch 49, Training Loss: 0.7753388285636902, Train F1: 0.3125, Validation F1: 0.2667
# Epoch 50, Training Loss: 0.7742835879325867, Train F1: 0.3125, Validation F1: 0.2667
# Epoch 51, Training Loss: 0.773260235786438, Train F1: 0.3125, Validation F1: 0.2667
# Epoch 52, Training Loss: 0.7722700834274292, Train F1: 0.3125, Validation F1: 0.2667
# Epoch 53, Training Loss: 0.7713009119033813, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 54, Training Loss: 0.770350992679596, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 55, Training Loss: 0.7694199681282043, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 56, Training Loss: 0.7685075998306274, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 57, Training Loss: 0.7676133513450623, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 58, Training Loss: 0.7667372226715088, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 59, Training Loss: 0.7658786773681641, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 60, Training Loss: 0.7650374174118042, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 61, Training Loss: 0.764212965965271, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 62, Training Loss: 0.7634052634239197, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 63, Training Loss: 0.7626137733459473, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 64, Training Loss: 0.7618380784988403, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 65, Training Loss: 0.7610778212547302, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 66, Training Loss: 0.7603328227996826, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 67, Training Loss: 0.759602427482605, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 68, Training Loss: 0.7588866353034973, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 69, Training Loss: 0.7581848502159119, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 70, Training Loss: 0.7574968338012695, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 71, Training Loss: 0.7568221092224121, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 72, Training Loss: 0.7561604380607605, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 73, Training Loss: 0.755511462688446, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 74, Training Loss: 0.7548749446868896, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 75, Training Loss: 0.7542505860328674, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 76, Training Loss: 0.7536376118659973, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 77, Training Loss: 0.7530363202095032, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 78, Training Loss: 0.752446174621582, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 79, Training Loss: 0.7518668174743652, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 80, Training Loss: 0.7512980699539185, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 81, Training Loss: 0.7507399320602417, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 82, Training Loss: 0.7501872181892395, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 83, Training Loss: 0.7496381998062134, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 84, Training Loss: 0.7490850687026978, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 85, Training Loss: 0.748514711856842, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 86, Training Loss: 0.7479116916656494, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 87, Training Loss: 0.7472791075706482, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 88, Training Loss: 0.746635913848877, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 89, Training Loss: 0.745987594127655, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 90, Training Loss: 0.7453362345695496, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 91, Training Loss: 0.7446821928024292, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 92, Training Loss: 0.7440239191055298, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 93, Training Loss: 0.7433629631996155, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 94, Training Loss: 0.7427034974098206, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 95, Training Loss: 0.7420467138290405, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 96, Training Loss: 0.7413933873176575, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 97, Training Loss: 0.7407447099685669, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 98, Training Loss: 0.7401013374328613, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 99, Training Loss: 0.7394634485244751, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 100, Training Loss: 0.7388314008712769, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 101, Training Loss: 0.7382182478904724, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 102, Training Loss: 0.737614631652832, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 103, Training Loss: 0.7370158433914185, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 104, Training Loss: 0.736423134803772, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 105, Training Loss: 0.7358370423316956, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 106, Training Loss: 0.7352582216262817, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 107, Training Loss: 0.734687089920044, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 108, Training Loss: 0.7341238260269165, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 109, Training Loss: 0.7335681915283203, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 110, Training Loss: 0.7330204844474792, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 111, Training Loss: 0.7324805855751038, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 112, Training Loss: 0.7319485545158386, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 113, Training Loss: 0.7314242124557495, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 114, Training Loss: 0.7309079170227051, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 115, Training Loss: 0.730398952960968, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 116, Training Loss: 0.7298974990844727, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 117, Training Loss: 0.7294036149978638, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 118, Training Loss: 0.7289170026779175, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 119, Training Loss: 0.7284368276596069, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 120, Training Loss: 0.7278929948806763, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 121, Training Loss: 0.7273224592208862, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 122, Training Loss: 0.7267417907714844, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 123, Training Loss: 0.7261531949043274, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 124, Training Loss: 0.7255581021308899, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 125, Training Loss: 0.724952757358551, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 126, Training Loss: 0.7243452072143555, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 127, Training Loss: 0.7237361073493958, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 128, Training Loss: 0.7231262922286987, Train F1: 0.3125, Validation F1: 0.2000
# Epoch 129, Training Loss: 0.7225167751312256, Train F1: 0.3125, Validation F1: 0.2333
# Epoch 130, Training Loss: 0.721908688545227, Train F1: 0.3125, Validation F1: 0.2333
# Epoch 131, Training Loss: 0.7213026881217957, Train F1: 0.3125, Validation F1: 0.3000
# Epoch 132, Training Loss: 0.720699667930603, Train F1: 0.3125, Validation F1: 0.2667
# Epoch 133, Training Loss: 0.7201005220413208, Train F1: 0.3125, Validation F1: 0.3667
# Epoch 134, Training Loss: 0.7195065021514893, Train F1: 0.3125, Validation F1: 0.3667
# Epoch 135, Training Loss: 0.7189186215400696, Train F1: 0.3125, Validation F1: 0.3667
# Epoch 136, Training Loss: 0.7183365225791931, Train F1: 0.3125, Validation F1: 0.3667
# Epoch 137, Training Loss: 0.717759907245636, Train F1: 0.3125, Validation F1: 0.3667
# Epoch 138, Training Loss: 0.7171886563301086, Train F1: 0.3125, Validation F1: 0.3667
# Epoch 139, Training Loss: 0.7166221737861633, Train F1: 0.3125, Validation F1: 0.3667
# Epoch 140, Training Loss: 0.7160629034042358, Train F1: 0.3125, Validation F1: 0.3667
# Epoch 141, Training Loss: 0.7155162692070007, Train F1: 0.3500, Validation F1: 0.3667
# Epoch 142, Training Loss: 0.7149820327758789, Train F1: 0.4125, Validation F1: 0.3667
# Epoch 143, Training Loss: 0.7144554853439331, Train F1: 0.4875, Validation F1: 0.3667
# Epoch 144, Training Loss: 0.713934063911438, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 145, Training Loss: 0.7134174704551697, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 146, Training Loss: 0.7129060626029968, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 147, Training Loss: 0.7124057412147522, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 148, Training Loss: 0.7119180560112, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 149, Training Loss: 0.7114353179931641, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 150, Training Loss: 0.7109571695327759, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 151, Training Loss: 0.710483729839325, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 152, Training Loss: 0.710015058517456, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 153, Training Loss: 0.7095513343811035, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 154, Training Loss: 0.7090923190116882, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 155, Training Loss: 0.7086381912231445, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 156, Training Loss: 0.7081888914108276, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 157, Training Loss: 0.707744300365448, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 158, Training Loss: 0.7073045969009399, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 159, Training Loss: 0.7068694829940796, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 160, Training Loss: 0.7064390778541565, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 161, Training Loss: 0.7060133814811707, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 162, Training Loss: 0.7055922150611877, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 163, Training Loss: 0.705175518989563, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 164, Training Loss: 0.7047632932662964, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 165, Training Loss: 0.7043554782867432, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 166, Training Loss: 0.7039519548416138, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 167, Training Loss: 0.7035526633262634, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 168, Training Loss: 0.7031576037406921, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 169, Training Loss: 0.7027665376663208, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 170, Training Loss: 0.702379584312439, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 171, Training Loss: 0.7019965648651123, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 172, Training Loss: 0.7016174793243408, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 173, Training Loss: 0.7012420892715454, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 174, Training Loss: 0.7008703351020813, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 175, Training Loss: 0.7004977464675903, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 176, Training Loss: 0.7001228928565979, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 177, Training Loss: 0.6997389197349548, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 178, Training Loss: 0.6993288993835449, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 179, Training Loss: 0.6988940238952637, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 180, Training Loss: 0.6984434723854065, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 181, Training Loss: 0.6979929208755493, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 182, Training Loss: 0.6975470781326294, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 183, Training Loss: 0.6971081495285034, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 184, Training Loss: 0.696672797203064, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 185, Training Loss: 0.6962252855300903, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 186, Training Loss: 0.6957685351371765, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 187, Training Loss: 0.6953064799308777, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 188, Training Loss: 0.6948405504226685, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 189, Training Loss: 0.6944385766983032, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 190, Training Loss: 0.6940728425979614, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 191, Training Loss: 0.6937122344970703, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 192, Training Loss: 0.6933490633964539, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 193, Training Loss: 0.6929845213890076, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 194, Training Loss: 0.6926192045211792, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 195, Training Loss: 0.6922587752342224, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 196, Training Loss: 0.6919378042221069, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 197, Training Loss: 0.6916157007217407, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 198, Training Loss: 0.691286563873291, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 199, Training Loss: 0.6909523010253906, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 200, Training Loss: 0.6906145215034485, Train F1: 0.5125, Validation F1: 0.3667

# %% [markdown]
# ### Q3.2.c - Training the Model on Merged Graphs G = G1 ∪ G
#
# • Implement a GCN that trains on both graphs at once. Plot the training curve.
#
# • Compare the performance of G = G1 ∪ G2 against training on G1 and G2, respectively.
#
# • Plot TSNE plots.

# %%
# SOLUTION Q3.2.c
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

# Implement the training of G = {G1 U G2}
def merge_graphs(G1, G2):
    """
    Merges two graphs G1 and G2 into a single graph G.
    """
    G = patch_A_for_dataset([G1, G2]) # list of [(X,A,y) for each graph]

    # Merge the features
    X = torch.cat((G[0][0], G[1][0]), dim=0)
    # Merge the labels
    y = torch.cat((G[0][2], G[1][2]), dim=0)

    # Merge the adjacency matrices
    A1 = G[0][1]
    A2 = G[1][1]
    N1 = A1.size(0)
    A = torch.zeros((N1+A2.size(0), N1+A2.size(0)))
    A[:N1, :N1] = A1
    A[N1:, N1:] = A2

    return X, A, y

# In the end return a single function:
def train_G1UG2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True, return_embeddings=True, num_layers=2):
    """"""
    # Initialising the model
    input_dim = 10
    hidden_dim = 8

    G_train = merge_graphs(G1_train, G2_train)
    G_eval = merge_graphs(G1_eval, G2_eval)

    model = LayeredGraphNeuralNetwork(input_dim, hidden_dim, num_layers)
    print(model)

    losses, train_f1, val_f1, last_embeddings = train_model(
        model,
        G_train,
        G_eval,
        num_epochs=num_epochs,
        lr=lr,
        verbose=verbose,
        return_embeddings=return_embeddings
    )
    if return_embeddings:
        return losses, train_f1, val_f1, last_embeddings
    return losses, train_f1, val_f1

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Running the evaluation.

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

print("Training on G = {G1 U G2}")

losses, train_f1, val_f1, last_embeddings = train_G1UG2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True, return_embeddings=True)

plot_training_and_validation(losses, val_f1, graph1_label="Training Loss", graph2_label="Validation F1", x_label="Epoch", title="Training Loss and Validation F1 Over Time (Merged Graphs)", save=False, plot_name="training_validation_f1")
plot_training_and_validation(train_f1, val_f1, graph1_label="Training F1", graph2_label="Validation F1", x_label="Epoch", title="Training and Validation F1 Over Time (Merged Graphs)", save=False, plot_name="training_validation_f1")

# print(len(last_embeddings))
plot_tsne(last_embeddings, G1_train[2], save=False, plot_name=f"tSNE_layer_{str(len(last_embeddings))}")
# Out:
# Training on G = {G1 U G2}
# Created model with variable number of GCN Layers
# LayeredGraphNeuralNetwork(
#   (layers): ModuleList(
#     (0-1): 2 x GCNLayer()
#   )
# )
# Epoch 1, Training Loss: 0.7978619337081909, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 2, Training Loss: 0.7953906059265137, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 3, Training Loss: 0.7929295301437378, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 4, Training Loss: 0.7904754281044006, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 5, Training Loss: 0.7880411148071289, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 6, Training Loss: 0.7856067419052124, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 7, Training Loss: 0.7831777334213257, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 8, Training Loss: 0.7807542681694031, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 9, Training Loss: 0.7783340811729431, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 10, Training Loss: 0.7759397625923157, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 11, Training Loss: 0.7735607028007507, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 12, Training Loss: 0.7711943984031677, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 13, Training Loss: 0.7688481211662292, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 14, Training Loss: 0.7665179967880249, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 15, Training Loss: 0.7642062306404114, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 16, Training Loss: 0.7619208097457886, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 17, Training Loss: 0.7596541047096252, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 18, Training Loss: 0.7574032545089722, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 19, Training Loss: 0.7551814317703247, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 20, Training Loss: 0.7529789209365845, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 21, Training Loss: 0.7507967948913574, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 22, Training Loss: 0.7486333250999451, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 23, Training Loss: 0.7464927434921265, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 24, Training Loss: 0.7443742156028748, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 25, Training Loss: 0.742280125617981, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 26, Training Loss: 0.7402058839797974, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 27, Training Loss: 0.7381635308265686, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 28, Training Loss: 0.7361432313919067, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 29, Training Loss: 0.734148383140564, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 30, Training Loss: 0.7321819067001343, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 31, Training Loss: 0.7302343249320984, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 32, Training Loss: 0.7282968759536743, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 33, Training Loss: 0.7263807058334351, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 34, Training Loss: 0.7244924306869507, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 35, Training Loss: 0.7226234674453735, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 36, Training Loss: 0.7207604646682739, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 37, Training Loss: 0.7189116477966309, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 38, Training Loss: 0.717079222202301, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 39, Training Loss: 0.7152655720710754, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 40, Training Loss: 0.7134665846824646, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 41, Training Loss: 0.7116832733154297, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 42, Training Loss: 0.7099142074584961, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 43, Training Loss: 0.7081609964370728, Train F1: 0.4938, Validation F1: 0.4333
# Epoch 44, Training Loss: 0.7064245343208313, Train F1: 0.4938, Validation F1: 0.4333
# Epoch 45, Training Loss: 0.704703152179718, Train F1: 0.5000, Validation F1: 0.4333
# Epoch 46, Training Loss: 0.7030161023139954, Train F1: 0.5000, Validation F1: 0.4333
# Epoch 47, Training Loss: 0.7013519406318665, Train F1: 0.5062, Validation F1: 0.4333
# Epoch 48, Training Loss: 0.6997078657150269, Train F1: 0.5062, Validation F1: 0.4333
# Epoch 49, Training Loss: 0.6980903744697571, Train F1: 0.5062, Validation F1: 0.4333
# Epoch 50, Training Loss: 0.6964908838272095, Train F1: 0.5125, Validation F1: 0.4500
# Epoch 51, Training Loss: 0.6948875188827515, Train F1: 0.5125, Validation F1: 0.4500
# Epoch 52, Training Loss: 0.6933029890060425, Train F1: 0.5125, Validation F1: 0.4500
# Epoch 53, Training Loss: 0.6917330622673035, Train F1: 0.5188, Validation F1: 0.4667
# Epoch 54, Training Loss: 0.6901839971542358, Train F1: 0.5125, Validation F1: 0.4667
# Epoch 55, Training Loss: 0.6886529922485352, Train F1: 0.5188, Validation F1: 0.4667
# Epoch 56, Training Loss: 0.6871246695518494, Train F1: 0.5188, Validation F1: 0.4667
# Epoch 57, Training Loss: 0.68560391664505, Train F1: 0.5250, Validation F1: 0.4667
# Epoch 58, Training Loss: 0.6840938925743103, Train F1: 0.5188, Validation F1: 0.4833
# Epoch 59, Training Loss: 0.682600200176239, Train F1: 0.5188, Validation F1: 0.4833
# Epoch 60, Training Loss: 0.6811262369155884, Train F1: 0.5312, Validation F1: 0.4667
# Epoch 61, Training Loss: 0.6796521544456482, Train F1: 0.5375, Validation F1: 0.4667
# Epoch 62, Training Loss: 0.6781886219978333, Train F1: 0.5375, Validation F1: 0.4833
# Epoch 63, Training Loss: 0.6767366528511047, Train F1: 0.5375, Validation F1: 0.4833
# Epoch 64, Training Loss: 0.6753019094467163, Train F1: 0.5437, Validation F1: 0.4833
# Epoch 65, Training Loss: 0.6738735437393188, Train F1: 0.5625, Validation F1: 0.4833
# Epoch 66, Training Loss: 0.6724482178688049, Train F1: 0.5625, Validation F1: 0.4667
# Epoch 67, Training Loss: 0.6710320711135864, Train F1: 0.5750, Validation F1: 0.4667
# Epoch 68, Training Loss: 0.669631838798523, Train F1: 0.5875, Validation F1: 0.4833
# Epoch 69, Training Loss: 0.6682468056678772, Train F1: 0.5938, Validation F1: 0.4833
# Epoch 70, Training Loss: 0.666878342628479, Train F1: 0.5938, Validation F1: 0.5000
# Epoch 71, Training Loss: 0.665526270866394, Train F1: 0.6125, Validation F1: 0.5167
# Epoch 72, Training Loss: 0.6641908288002014, Train F1: 0.6250, Validation F1: 0.5333
# Epoch 73, Training Loss: 0.6628599762916565, Train F1: 0.6438, Validation F1: 0.5333
# Epoch 74, Training Loss: 0.6615434885025024, Train F1: 0.6500, Validation F1: 0.5500
# Epoch 75, Training Loss: 0.6602416634559631, Train F1: 0.6687, Validation F1: 0.5500
# Epoch 76, Training Loss: 0.6589428186416626, Train F1: 0.6687, Validation F1: 0.5500
# Epoch 77, Training Loss: 0.6576507687568665, Train F1: 0.6687, Validation F1: 0.5667
# Epoch 78, Training Loss: 0.656370997428894, Train F1: 0.6687, Validation F1: 0.5667
# Epoch 79, Training Loss: 0.6551052927970886, Train F1: 0.6625, Validation F1: 0.5667
# Epoch 80, Training Loss: 0.6538535952568054, Train F1: 0.6625, Validation F1: 0.5500
# Epoch 81, Training Loss: 0.6526142358779907, Train F1: 0.6625, Validation F1: 0.5500
# Epoch 82, Training Loss: 0.6513874530792236, Train F1: 0.6625, Validation F1: 0.5500
# Epoch 83, Training Loss: 0.6501737833023071, Train F1: 0.6625, Validation F1: 0.5500
# Epoch 84, Training Loss: 0.6489728689193726, Train F1: 0.6625, Validation F1: 0.5500
# Epoch 85, Training Loss: 0.647781252861023, Train F1: 0.6625, Validation F1: 0.5500
# Epoch 86, Training Loss: 0.6466013193130493, Train F1: 0.6687, Validation F1: 0.5500
# Epoch 87, Training Loss: 0.6454384922981262, Train F1: 0.6687, Validation F1: 0.5500
# Epoch 88, Training Loss: 0.6442784667015076, Train F1: 0.6687, Validation F1: 0.5500
# Epoch 89, Training Loss: 0.6431277990341187, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 90, Training Loss: 0.6419950723648071, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 91, Training Loss: 0.6408736705780029, Train F1: 0.6750, Validation F1: 0.5667
# Epoch 92, Training Loss: 0.6397636532783508, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 93, Training Loss: 0.6386647820472717, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 94, Training Loss: 0.6375779509544373, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 95, Training Loss: 0.6365039348602295, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 96, Training Loss: 0.6354409456253052, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 97, Training Loss: 0.6343886852264404, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 98, Training Loss: 0.63334721326828, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 99, Training Loss: 0.632316529750824, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 100, Training Loss: 0.6312965154647827, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 101, Training Loss: 0.6302875280380249, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 102, Training Loss: 0.6292896270751953, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 103, Training Loss: 0.628301739692688, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 104, Training Loss: 0.6273239254951477, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 105, Training Loss: 0.6263545751571655, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 106, Training Loss: 0.6253955960273743, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 107, Training Loss: 0.6244462728500366, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 108, Training Loss: 0.6235080361366272, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 109, Training Loss: 0.6225810647010803, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 110, Training Loss: 0.6216632127761841, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 111, Training Loss: 0.6207557916641235, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 112, Training Loss: 0.6198580861091614, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 113, Training Loss: 0.618969202041626, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 114, Training Loss: 0.6180893182754517, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 115, Training Loss: 0.6172206401824951, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 116, Training Loss: 0.6163649559020996, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 117, Training Loss: 0.6155205965042114, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 118, Training Loss: 0.6146891713142395, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 119, Training Loss: 0.6138683557510376, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 120, Training Loss: 0.613057553768158, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 121, Training Loss: 0.6122547388076782, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 122, Training Loss: 0.6114588975906372, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 123, Training Loss: 0.610670268535614, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 124, Training Loss: 0.6098874807357788, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 125, Training Loss: 0.6091135740280151, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 126, Training Loss: 0.6083477139472961, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 127, Training Loss: 0.60759437084198, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 128, Training Loss: 0.6068491339683533, Train F1: 0.6813, Validation F1: 0.5500
# Epoch 129, Training Loss: 0.6061106324195862, Train F1: 0.6813, Validation F1: 0.5500
# Epoch 130, Training Loss: 0.6053845286369324, Train F1: 0.6875, Validation F1: 0.5500
# Epoch 131, Training Loss: 0.6046661734580994, Train F1: 0.6875, Validation F1: 0.5500
# Epoch 132, Training Loss: 0.6039563417434692, Train F1: 0.6875, Validation F1: 0.5500
# Epoch 133, Training Loss: 0.603253185749054, Train F1: 0.6875, Validation F1: 0.5500
# Epoch 134, Training Loss: 0.6025563478469849, Train F1: 0.6937, Validation F1: 0.5500
# Epoch 135, Training Loss: 0.6018689870834351, Train F1: 0.6937, Validation F1: 0.5500
# Epoch 136, Training Loss: 0.6011881828308105, Train F1: 0.7000, Validation F1: 0.5500
# Epoch 137, Training Loss: 0.6005135774612427, Train F1: 0.7063, Validation F1: 0.5500
# Epoch 138, Training Loss: 0.5998451709747314, Train F1: 0.7063, Validation F1: 0.5500
# Epoch 139, Training Loss: 0.5991836786270142, Train F1: 0.7000, Validation F1: 0.5500
# Epoch 140, Training Loss: 0.5985320210456848, Train F1: 0.6875, Validation F1: 0.5500
# Epoch 141, Training Loss: 0.5978862047195435, Train F1: 0.6813, Validation F1: 0.5500
# Epoch 142, Training Loss: 0.5972455739974976, Train F1: 0.6937, Validation F1: 0.5500
# Epoch 143, Training Loss: 0.596609890460968, Train F1: 0.6937, Validation F1: 0.5667
# Epoch 144, Training Loss: 0.5959787964820862, Train F1: 0.7000, Validation F1: 0.5667
# Epoch 145, Training Loss: 0.5953549742698669, Train F1: 0.6937, Validation F1: 0.5667
# Epoch 146, Training Loss: 0.5947370529174805, Train F1: 0.7000, Validation F1: 0.5667
# Epoch 147, Training Loss: 0.5941239595413208, Train F1: 0.7000, Validation F1: 0.5667
# Epoch 148, Training Loss: 0.5935155749320984, Train F1: 0.7063, Validation F1: 0.5667
# Epoch 149, Training Loss: 0.5929129719734192, Train F1: 0.7125, Validation F1: 0.5667
# Epoch 150, Training Loss: 0.5923154950141907, Train F1: 0.7188, Validation F1: 0.5667
# Epoch 151, Training Loss: 0.5917249321937561, Train F1: 0.7188, Validation F1: 0.5667
# Epoch 152, Training Loss: 0.5911387205123901, Train F1: 0.7125, Validation F1: 0.5667
# Epoch 153, Training Loss: 0.5905569195747375, Train F1: 0.7375, Validation F1: 0.5667
# Epoch 154, Training Loss: 0.5899800062179565, Train F1: 0.7375, Validation F1: 0.5833
# Epoch 155, Training Loss: 0.5894072651863098, Train F1: 0.7438, Validation F1: 0.6000
# Epoch 156, Training Loss: 0.5888386368751526, Train F1: 0.7438, Validation F1: 0.6000
# Epoch 157, Training Loss: 0.5882740020751953, Train F1: 0.7375, Validation F1: 0.5833
# Epoch 158, Training Loss: 0.5877133011817932, Train F1: 0.7375, Validation F1: 0.5833
# Epoch 159, Training Loss: 0.5871564149856567, Train F1: 0.7375, Validation F1: 0.5833
# Epoch 160, Training Loss: 0.5866032838821411, Train F1: 0.7438, Validation F1: 0.5833
# Epoch 161, Training Loss: 0.5860543847084045, Train F1: 0.7438, Validation F1: 0.6000
# Epoch 162, Training Loss: 0.5855093598365784, Train F1: 0.7438, Validation F1: 0.6000
# Epoch 163, Training Loss: 0.5849679708480835, Train F1: 0.7438, Validation F1: 0.6167
# Epoch 164, Training Loss: 0.5844296216964722, Train F1: 0.7562, Validation F1: 0.6167
# Epoch 165, Training Loss: 0.5838951468467712, Train F1: 0.7562, Validation F1: 0.6333
# Epoch 166, Training Loss: 0.5833650827407837, Train F1: 0.7562, Validation F1: 0.6333
# Epoch 167, Training Loss: 0.5828386545181274, Train F1: 0.7562, Validation F1: 0.6333
# Epoch 168, Training Loss: 0.582316517829895, Train F1: 0.7562, Validation F1: 0.6333
# Epoch 169, Training Loss: 0.5817981362342834, Train F1: 0.7562, Validation F1: 0.6333
# Epoch 170, Training Loss: 0.5812832713127136, Train F1: 0.7562, Validation F1: 0.6333
# Epoch 171, Training Loss: 0.5807719826698303, Train F1: 0.7562, Validation F1: 0.6333
# Epoch 172, Training Loss: 0.5802642107009888, Train F1: 0.7562, Validation F1: 0.6500
# Epoch 173, Training Loss: 0.5797598958015442, Train F1: 0.7562, Validation F1: 0.6667
# Epoch 174, Training Loss: 0.5792592167854309, Train F1: 0.7562, Validation F1: 0.6667
# Epoch 175, Training Loss: 0.578761875629425, Train F1: 0.7562, Validation F1: 0.6667
# Epoch 176, Training Loss: 0.5782676935195923, Train F1: 0.7562, Validation F1: 0.6667
# Epoch 177, Training Loss: 0.577777087688446, Train F1: 0.7562, Validation F1: 0.6667
# Epoch 178, Training Loss: 0.5772900581359863, Train F1: 0.7562, Validation F1: 0.6667
# Epoch 179, Training Loss: 0.5768061876296997, Train F1: 0.7562, Validation F1: 0.6667
# Epoch 180, Training Loss: 0.5763254165649414, Train F1: 0.7562, Validation F1: 0.6833
# Epoch 181, Training Loss: 0.5758475065231323, Train F1: 0.7562, Validation F1: 0.6833
# Epoch 182, Training Loss: 0.5753727555274963, Train F1: 0.7562, Validation F1: 0.6833
# Epoch 183, Training Loss: 0.5749009847640991, Train F1: 0.7562, Validation F1: 0.6833
# Epoch 184, Training Loss: 0.5744322538375854, Train F1: 0.7562, Validation F1: 0.6833
# Epoch 185, Training Loss: 0.5739668011665344, Train F1: 0.7625, Validation F1: 0.6833
# Epoch 186, Training Loss: 0.5735044479370117, Train F1: 0.7625, Validation F1: 0.6833
# Epoch 187, Training Loss: 0.5730454325675964, Train F1: 0.7625, Validation F1: 0.6833
# Epoch 188, Training Loss: 0.572589635848999, Train F1: 0.7625, Validation F1: 0.6833
# Epoch 189, Training Loss: 0.5721368193626404, Train F1: 0.7625, Validation F1: 0.6833
# Epoch 190, Training Loss: 0.5716871619224548, Train F1: 0.7625, Validation F1: 0.7000
# Epoch 191, Training Loss: 0.5712404847145081, Train F1: 0.7625, Validation F1: 0.7000
# Epoch 192, Training Loss: 0.5707969665527344, Train F1: 0.7625, Validation F1: 0.7000
# Epoch 193, Training Loss: 0.5703566670417786, Train F1: 0.7625, Validation F1: 0.7000
# Epoch 194, Training Loss: 0.5699189901351929, Train F1: 0.7625, Validation F1: 0.7167
# Epoch 195, Training Loss: 0.5694842338562012, Train F1: 0.7625, Validation F1: 0.7167
# Epoch 196, Training Loss: 0.5690523982048035, Train F1: 0.7625, Validation F1: 0.7167
# Epoch 197, Training Loss: 0.5686239004135132, Train F1: 0.7625, Validation F1: 0.7167
# Epoch 198, Training Loss: 0.5681989789009094, Train F1: 0.7625, Validation F1: 0.7167
# Epoch 199, Training Loss: 0.5677797198295593, Train F1: 0.7625, Validation F1: 0.7167
# Epoch 200, Training Loss: 0.5673645734786987, Train F1: 0.7625, Validation F1: 0.7167

# %% [markdown]
# ### Q3.2.d Implement & discuss what you observe.
#
# • Compare training results, embeddings, and overall observations between independent and
# merged training.
#
# • Formulate a hypothesis explaining your observations.
#
# • Discuss different implementation options for training on both graphs, including your choice.
# (e.g. what model modifications are possible; what training modifications are possible?)
#
# • Provide relevant plots and tables where appropriate.
#
# • Bonus: Implement a modification (or alternative approach) for training on G1 ∪ G2 and
# compare outcomes.

# %%
# SOLUTION Q3.2.d
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

# Implement the training of G = {G1 U G2}

# In the end return a single function:
def train_G1UG2_v2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True):
    """"""
    # INSERT necessary things
    return losses, train_f1, val_f1

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Runnning the evaluation.
#
# Note: It is optional to run this particular evaluation. You can modify it as needed.

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

losses, train_f1, val_f1 = train_G1UG2_v2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True)

plot_training_and_validation(losses, val_f1)

# %% [markdown]
# ## 3.3 Topological changes to improve training

# %% [markdown]
# ### Q3.3.a - Plot the Ricci Curvature for each edge.
#
# • Plot a barplot of the the Ricci curvature per edge, where the x-axis are the edges and y-axis
# is the ricci curvature.

# %%
# Plot curvature against edges
from graph_ricci_curvature import GraphRicciCurvature 

def plot_ricci_per_edge(A, color="cornflowerblue", dataset_name='Training', save=False, plot_name=""):
    """
    Plot the Ricci Curvature per edge in the graph, with the Ricci Curvature
    on the y-axis and the edge count on the x-axis.
    """
    G = nx.from_numpy_array(A.numpy())

    ricci_curvature = GraphRicciCurvature(G)
    curvatures_per_edge = ricci_curvature.compute_ricci_curvatures()

    # After computation, the Ricci curvature for each edge is stored in G[u][v]["ricciCurvature"]
    ricci_values = []
    edge_labels = []
    for (u, v), val in curvatures_per_edge.items():
        ricci_values.append(val)
        edge_labels.append((u, v))

    W, H = 15, 15
    if len(ricci_values) > 50:
        W, H = 30, 30
    plt.figure(figsize=(W, H))
    fig, ax = plt.subplots(figsize=(12, 6))
    ax.bar([i for i in range(len(ricci_values))], ricci_values, color=color, label="Graph 1", edgecolor='navy', alpha=0.6)
    ax.set_xticklabels(edge_labels)

    plt.grid(True, alpha=0.5)

    plt.xlabel('Edge')
    plt.ylabel('Ricci Curvature')
    plt.title(f'Comparison of Oliver-Ricci Curvature\n{dataset_name} Dataset')
    plt.legend()
    if save:
        fig_name = f"images/Q3/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# %%
# SOLUTION Q3.3.a
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  


# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label


plot_ricci_per_edge(G1_train[1], dataset_name='G1 Training', color='cornflowerblue', save=True, plot_name="ricci_per_edge_G1_training")
plot_ricci_per_edge(G1_eval[1], dataset_name='G1 Eval', color='cornflowerblue', save=True, plot_name="ricci_per_edge_G1_eval")
plot_ricci_per_edge(G2_train[1], dataset_name='G2 Training', color='orchid', save=True, plot_name="ricci_per_edge_G2_training")
plot_ricci_per_edge(G2_eval[1], dataset_name='G1 Eval', color='orchid', save=True, plot_name="ricci_per_edge_G2_eval")


# ####################################################
# END OF MODIFICATION
# ####################################################
# Out:
# /var/folders/vr/t_3rc9l16fzfc__65h566qhw0000gn/T/ipykernel_90506/2832203588.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(edge_labels)
# /var/folders/vr/t_3rc9l16fzfc__65h566qhw0000gn/T/ipykernel_90506/2832203588.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(edge_labels)
# /var/folders/vr/t_3rc9l16fzfc__65h566qhw0000gn/T/ipykernel_90506/2832203588.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(edge_labels)
# /var/folders/vr/t_3rc9l16fzfc__65h566qhw0000gn/T/ipykernel_90506/2832203588.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(edge_labels)

# %% [markdown]
# ### Q3.3.b Investigate the extreme case topologies.
#
# • How would you modify a topology so that the graph structure is ignored, making the GNN
# behave like an MLP?
#
# • What would an ideal graph structure be for optimal training and testing if labels were
# available (both during training and testing)?
#
# • What are you observations? Analyze the scores and what does it mean about the dataset?
#
# • Provide relevant plots and results.

# %%
# SOLUTION Q3.3.b
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def augment_graph_gold_labels(G):
    """Augment graph to return A that would be 'perfect'"""
    X,A,y = G
    return X,A,y

def augment_graph_no_effect(G):
    """Modify graph to return A that has no 'effect'"""
    X,A,y = G
    return X,A,y

    
def improved_training(
        G_train,
        G_eval,
        model_params,
        num_epochs=200,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = {},
    ):
    """
    How can you improve the topologies to train better.
    """
    if change_topology_params["augmentation_strategy"] == "no_effect":
        augmentation_function = augment_graph_no_effect
    elif change_topology_params["augmentation_strategy"] == "gold":
        augmentation_function = augment_graph_gold_labels
    else:
        raise NotImplementedError("This augmentation setting is not implemented.")

    G_train = augmentation_function(G_train)
    G_train = G_train[0],symmetric_normalize(G_train[1]),G_train[2]

    G_eval = augmentation_function(G_eval)
    G_eval = G_eval[0],symmetric_normalize(G_eval[1]),G_eval[2]

    # Initialising the model
    model = LayeredGraphNeuralNetwork(**model_params)
    print(model)

    losses, train_f1, val_f1, last_embeddings = train_model(
        model,
        G_train,
        G_eval,
        num_epochs=num_epochs,
        lr=lr,
        verbose=verbose,
        return_embeddings = return_embeddings
    )
    return losses, train_f1, val_f1, last_embeddings

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Code to run improvement
# Note: run it a few times to see what performance can be reached on the eval dataset.

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

model_params = {    
    "input_dim":10, 
    "hidden_dim":8,
    "num_layers":4,
}

change_topology_params = {
    "augmentation_strategy":"no_effect",
    "normalise" : False,
}

# change_topology_params = {
#     "augmentation_strategy":"gold",
#     "normalise" : True,

# }

losses, train_f1, val_f1, last_embeddings = improved_training(
    G2_train,
    G2_eval,
    model_params=model_params,
    num_epochs=250,
    lr=0.0005,
    verbose=True,
    return_embeddings = True,
    change_topology_params = change_topology_params #change as needed
)
plot_training_and_validation(losses, val_f1)

X,A,y = G1_train
print(len(last_embeddings))
plot_tsne(last_embeddings, y)

# %% [markdown]
# ### Q3.3.C Improving Graph Topology for Better Learning
#
# • Implement two graph modifications.
#
# • Describe your modifications.
#
# • What motivated your implementation?
#
# • If it helped give a hypothesis on why you think that is? If it did not give a hypothesis why
# you think it did not help.
#
# • Provide relevant plots and results

# %%
# SOLUTION Q3.3.c
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def augment_graph(G):
    """Augments the graph."""
    X,A,y = G

    return X,A,y
    
def improved_training(
        G_train,
        G_eval,
        model_params,
        num_epochs=200,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = {},
    ):
    """
    How can you improve the topologies to train better.
    """

    G_train = augment_graph(G_train)
    G_train = G_train[0],symmetric_normalize(G_train[1]),G_train[2]

    G_eval = augment_graph(G_eval)
    G_eval = G_eval[0],symmetric_normalize(G_eval[1]),G_eval[2]

    # Initialising the model
    model = LayeredGraphNeuralNetwork(**model_params)
    print(model)

    losses, train_f1, val_f1, last_embeddings = train_model(
        model,
        G_train,
        G_eval,
        num_epochs=num_epochs,
        lr=lr,
        verbose=verbose,
        return_embeddings = True
    )
    return losses, train_f1, val_f1, last_embeddings

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Code to run improvement

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label


model_params = {    
    "input_dim":10, 
    "hidden_dim":8,
    "num_layers":4,
}

change_topology_params = {
    "augmentation_strategy":"eval",
}

losses, train_f1, val_f1, last_embeddings = improved_training(
    G2_train,
    G2_eval,
    model_params=model_params,
    num_epochs=200,
    lr=0.0005,
    verbose=True,
    return_embeddings = True,
    change_topology_params = change_topology_params #change as needed
)
plot_training_and_validation(losses, val_f1)

X,A,y = G1_train
print(len(last_embeddings))
plot_tsne(last_embeddings, y)
