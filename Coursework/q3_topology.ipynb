# %% [markdown]
# # Question 3: Investigating Topology in Node-Based Classification Using GNNs
#
# In this section, we will explore the impact of graph topology on node-based classification using GNNs. The experiments will focus on analyzing different topological measures, visualizing their distributions, and evaluating GCN performance on 2 graphs with different topologies.

# %%
import json
import torch
import os
import random
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import networkx as nx
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
from graph_ricci_curvature import GraphRicciCurvature

import seaborn as sns

# %% [markdown]
# ## Helper function and code for loading data

# %%
G1_TRAIN_FILE_NAME = "q3_G1_train.json"
G1_EVAL_FILE_NAME = "q3_G1_eval.json"

G1_TRAIN_DATA_PATH = os.path.join("data",G1_TRAIN_FILE_NAME)
G1_EVAL_DATA_PATH = os.path.join("data",G1_EVAL_FILE_NAME)

G2_TRAIN_FILE_NAME = "q3_G2_train.json"
G2_EVAL_FILE_NAME = "q3_G2_eval.json"

G2_TRAIN_DATA_PATH = os.path.join("data",G2_TRAIN_FILE_NAME)
G2_EVAL_DATA_PATH = os.path.join("data",G2_EVAL_FILE_NAME)

# %%
# Functions to load the data
def create_Adj_matrix(N, edge_index):
    """Creates the adjacency matrix"""
    A = torch.zeros((N, N), dtype=torch.float)
    for idx, jdx in edge_index:
        A[idx, jdx] = 1
        A[jdx, idx] = 1
    return A

def read_json_data(file_path, has_label=True):
    with open(file_path, 'r') as f:
        data = json.load(f)
    
    if not type(data) == list:
        item = data
        X = torch.tensor(item['features'], dtype=torch.float)
        N = len(X)
        A = create_Adj_matrix(N, item['edge_index'])
        if has_label:
            y = torch.tensor(item['label'], dtype=torch.long)
        else:
            y = None
        return (X,A,y)

    graph_data = []
    for item in data:
        X = torch.tensor(item['features'], dtype=torch.float)
        N = len(X)
        A = create_Adj_matrix(N, item['edge_index'])
        if has_label:
            y = torch.tensor(item['label'], dtype=torch.long)
        else:
            y = None
        
        graph_data.append((X,A,y))
    
    return graph_data

# %% [markdown]
# ## Question 3.1 - Analyzing the Graphs

# %% [markdown]
# ### Q3.1.b Visualizing and Comparing Topological and Geometric Measures of Two Graphs
#
# Implement the following three functions to visualize and compare structural properties of two given graphs:
#
# - `plot_node_degree_distribution_two_graphs`
# - `plot_betweenness_centrality_distribution_two_graphs`
# - `plot_ollivier_ricci_curvature_distribution_two_graphs`

# %%
def compute_node_degree(A):
    """
    Given an adjacency matrix A of shape (N, N),
    return the degree (row sum) for each of the N nodes.
    """
    degrees = A.sum(dim=1)  # sum across columns
    return degrees

# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  


def plot_node_degree_distribution_two_graphs(A1, A2, dataset_name='Training', save=False, plot_name=""):
    """
    Plots the node degree distributions of two graphs
    with adjacency matrices A1 and A2 (each of shape (N, N))
    in a single figure.
    
    """
    plt.figure(figsize=(15, 15))
    node_deg_dist_G1 = compute_node_degree(A1)
    node_deg_dist_G2 = compute_node_degree(A2)

    # ensure all bins have equal width
    G1_bins = np.unique(node_deg_dist_G1)
    G2_bins = np.unique(node_deg_dist_G2)
    
    fig, ax = plt.subplots(figsize=(12, 6))
    plt.hist(x=node_deg_dist_G1, color="cornflowerblue", label="Graph 1", edgecolor='navy', alpha=0.6, bins=G1_bins)
    plt.hist(x=node_deg_dist_G2, color="orchid", label="Graph 2", edgecolor='purple', alpha=0.6, bins=G2_bins)

    plt.grid(True, alpha=0.5)

    plt.xlabel('Degree')
    plt.ylabel('Node Count')
    plt.title(f'Comparison of Node Degree Distributions\n{dataset_name} Dataset')
    plt.legend()
    if save:
        fig_name = f"images/Q3/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def compute_betweenness_centrality(A):
    """
    Calculate the betweenness centrality of each node in the graph
    defined by the given adjacency matrix A.
    """
    G = nx.from_numpy_array(A.numpy())
    betweenness_centrality = nx.betweenness_centrality(G)
    betweenness_centrality = np.array(list(betweenness_centrality.values()))
    return betweenness_centrality

def plot_betweenness_distribution_two_graphs(A1, A2, dataset_name='Training', save=False, plot_name=""):
    """
    Plots the betweenness centrality distributions of two graphs
    defined by adjacency matrices A1 and A2 (each of shape (N, N)) 
    in a single figure.
    """
    plt.figure(figsize=(15, 15))
    betweenness_G1 = compute_betweenness_centrality(A1)
    betweenness_G2 = compute_betweenness_centrality(A2)
    
    fig, ax = plt.subplots(figsize=(12, 6))
    plt.hist(x=betweenness_G1, color="cornflowerblue", label="Graph 1", edgecolor='navy', alpha=0.6)
    plt.hist(x=betweenness_G2, color="orchid", label="Graph 2", edgecolor='purple', alpha=0.6)

    plt.grid(True, alpha=0.5)

    plt.xlabel('Betweenness Centrality')
    plt.ylabel('Node Count')
    plt.title(f'Comparison of Betweenness Centrality Distributions\n{dataset_name} Dataset')
    plt.legend()
    if save:
        fig_name = f"images/Q3/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def plot_ricci_curvature_distribution_two_graphs(A1, A2, dataset_name='Training', save=False, plot_name=""):
    """
    Plots the Ollivier-Ricci curvature distributions for two graphs
    defined by adjacency matrices A1 and A2 (PyTorch tensors).
    
    Parameters
    ----------
    A1, A2 : torch.Tensor
        Adjacency matrices for two undirected graphs (NxN).
    """
    # 1) Convert PyTorch adjacency -> NumPy -> NetworkX Graph
    A1_np = A1.numpy()
    A2_np = A2.numpy()

    G1 = nx.from_numpy_array(A1_np)
    G2 = nx.from_numpy_array(A2_np)

    # 2) Instantiate OllivierRicci object for each graph
    ricci_calculator_G1 = GraphRicciCurvature(G1)
    ricci_calculator_G2 = GraphRicciCurvature(G2)

    # 3) Compute the Ricci curvature
    curvatures1 = ricci_calculator_G1.compute_ricci_curvatures()
    curvatures2 = ricci_calculator_G2.compute_ricci_curvatures()

    # After computation, the Ricci curvature for each edge is stored in G[u][v]["ricciCurvature"]

    # 4) Gather edge-level Ricci curvature values
    ricci_values_G1 = []
    for (u, v), val in curvatures1.items():
        ricci_values_G1.append(val)

    ricci_values_G2 = []
    for (u, v), val in curvatures2.items():
        ricci_values_G2.append(val)

    # Continue with plotting ...

    plt.figure(figsize=(15, 15))
    fig, ax = plt.subplots(figsize=(12, 6))
    plt.hist(x=ricci_values_G1, color="cornflowerblue", label="Graph 1", edgecolor='navy', alpha=0.6)
    plt.hist(x=ricci_values_G2, color="orchid", label="Graph 2", edgecolor='purple', alpha=0.6)

    plt.grid(True, alpha=0.5)

    plt.xlabel('Ricci Curvature')
    plt.ylabel('Edge Count')
    plt.title(f'Comparison of Oliver-Ricci Curvature\n{dataset_name} Dataset')
    plt.legend()
    if save:
        fig_name = f"images/Q3/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# %%
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

# %%
plot_node_degree_distribution_two_graphs(G1_train[1], G2_train[1], dataset_name='Training', save=True, plot_name="node_deg_dist_training")
plot_node_degree_distribution_two_graphs(G1_eval[1], G2_eval[1], dataset_name='Validation', save=True, plot_name="node_deg_dist_eval")

# %%
plot_betweenness_distribution_two_graphs(G1_train[1], G2_train[1], dataset_name='Training', save=True, plot_name="betweenness_training")
plot_betweenness_distribution_two_graphs(G1_eval[1], G2_eval[1], dataset_name='Validation', save=True, plot_name="betweenness_eval")

# %%
plot_ricci_curvature_distribution_two_graphs(G1_train[1], G2_train[1], dataset_name='Training', save=True, plot_name="ricci_curvature_training")
plot_ricci_curvature_distribution_two_graphs(G1_eval[1], G2_eval[1], dataset_name='Validation', save=True, plot_name="ricci_curvature_eval")

# %% [markdown]
# ### Q3.1.c Visualizing the Graphs
#
# Implement the `plot_graph` function to generate visual representations of both graphs. Ensure that the plots are clear and well-formatted.

# %%
def plot_graph(A, nodecolor='cornflowerblue', graph_name='G', save=False, plot_name=""):
    """
    Plots a graph defined by adjacency matrix A.
    Parameters
    ----------
    A : torch.Tensor
        Adjacency matrix of shape (N, N).
    """
    plt.figure(figsize=(15, 15))
    G = nx.from_numpy_array(A.numpy())
    pos = nx.spring_layout(G, seed=0)

    nx.draw_networkx_nodes(G, pos,
                            node_color=nodecolor,
                            node_size=300,
                            linewidths=3)
    nx.draw_networkx_edges(G, pos, edge_color='gray')
    nx.draw_networkx_labels(G, pos, 
                            font_size=10,
                            clip_on=True)
    plt.title(f"Graph {graph_name}")
    plt.grid(False)
    if save:
        fig_name = f"images/Q3/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# %%
plot_graph(G1_train[1], nodecolor='cornflowerblue', graph_name='Training G1', save=True, plot_name="Training_Graph_G1")
plot_graph(G1_eval[1], nodecolor='cornflowerblue', graph_name='Eval G1', save=True, plot_name="Eval_Graph_G1")

# %%
plot_graph(G2_train[1], nodecolor='orchid', graph_name='Training G2', save=True, plot_name="Training_Graph_G2")
plot_graph(G2_eval[1], nodecolor='orchid', graph_name='Eval G2', save=True, plot_name="Eval_Graph_G2")

# %% [markdown]
# ### Q3.1.d Visualizing Node Feature Distributions
#
# - Implement the function `plot_node_feature_dist_by_class_two_graphs` to visualize the average node feature distribution per class for two given graphs.
#
# - Do not consider the distribution of a specific feature $ x_i $, consider the mean of the feature vector $ \mathbf{x} $ for each node.
#
# - The function should generate a plot similar to Figure 3 in the Coursework Desciription PDF.

# %%
# HELPER FUNCTION ADAPTED FROM Q2
def get_avg_node_features(X, y):
    """
    Get the average feature values for each node class.
    Params:
        - X (torch.Tensor): Graph Nodes
        - y (torch.Tensor): Node labels (0 or 1 for all nodes in the graph)
    Returns:
        - class0_features (np.array): average feature values for nodes with class 0
        - class1_features (np.array): average feature values for nodes with class 1
    """
    class0_features = []
    class1_features = []
    for node_index, node in enumerate(X):
        if y[node_index] == 0:
            class0_features.append(torch.mean(node))
        else:
            class1_features.append(torch.mean(node))    
    return class0_features, class1_features

def plot_node_feature_dist_by_class_two_graphs(X_G1, X_G2, y_G1, y_G2, dataset_name='Training', save=False, plot_name=""):
    """
    Plots the distribution of the average node features by class for two graphs.
    """
    class0_features_G1, class1_features_G1 = get_avg_node_features(X_G1, y_G1)
    class0_features_G2, class1_features_G2 = get_avg_node_features(X_G2, y_G2)
    
    # Convert to numpy arrays and get the first feature dimension
    fig, axes = plt.subplots(figsize=(20, 8), ncols=2, nrows=1)

    # Plot for Graph 1
    axes[0].grid(True)
    
    axes[0].hist(x=class0_features_G1, color="cornflowerblue", label="Class 0", alpha=0.6, edgecolor='navy')
    axes[0].hist(x=class1_features_G1, color="orchid", label="Class 1", alpha=0.6, edgecolor='purple')
    axes[0].set_title('Graph 1: Avg Feature Distribution by Class')

    axes[0].set_xlabel('Average Feature Value')
    axes[0].set_ylabel('Frequency')
    axes[0].legend()

    # Plot for Graph 2
    axes[1].grid(True)

    axes[1].hist(x=class0_features_G2, color="cornflowerblue", label="Class 0", alpha=0.6, edgecolor='navy')
    axes[1].hist(x=class1_features_G2, color="orchid", label="Class 1", alpha=0.6, edgecolor='purple')
    axes[1].set_title('Graph 2: Avg Feature Distribution by Class')

    axes[1].set_xlabel('Average Feature Value')
    axes[1].set_ylabel('Frequency')
    axes[1].legend()

    fig.suptitle(f'Comparison of Average Node Feature Distributions by Class\n{dataset_name} Dataset')
    
    if save:
        fig_name = f"images/Q3/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# %%
plot_node_feature_dist_by_class_two_graphs(G1_train[0], G2_train[0], G1_train[2], G2_train[2], dataset_name='Training', save=True, plot_name="feature_dist_by_graph_training")
plot_node_feature_dist_by_class_two_graphs(G1_eval[0], G2_eval[0], G1_eval[2], G2_eval[2], dataset_name='Validation', save=True, plot_name="feature_dist_by_graph_eval")

# %% [markdown]
# ## Question 3.2 -  Evaluating GCN Performance on Different Graph Structures

# %% [markdown]
# ### Helper functions for normalising the A matrix.

# %%
# Helper function to normalise the A matrix
def symmetric_normalize(A_tilde):
    """
    Performs symmetric normalization of A_tilde (Adj. matrix with self loops):
      A_norm = D^{-1/2} * A_tilde * D^{-1/2}
    Where D_{ii} = sum of row i in A_tilde.

    A_tilde (N, N): Adj. matrix with self loops
    Returns:
      A_norm : (N, N)
    """

    eps = 1e-5
    d = A_tilde.sum(dim=1) + eps
    D_inv = torch.diag(torch.pow(d, -0.5))
    return D_inv @ A_tilde @ D_inv


def patch_A_matrix(A):
    """Patches the A matrix"""
    A = A + torch.eye(A.size(0))
    A = symmetric_normalize(A)
    return A

def patch_A_for_dataset(dataset):
    """Patches the A matrix for a dataset (list)"""
    dataset = [ (X, patch_A_matrix(A), y) for X,A,y in dataset]
    return dataset

# %% [markdown]
# ### Helper function for plotting training runs.

# %%
# Helper function for plotting:

def plot_training_and_validation(training_losses, validation_losses, graph1_label="Training Accuracy", graph2_label="Validation Accuracy", x_label="Epoch", title=None, save=False, plot_name=""):
    """
    Plots the validation accuracy and training loss over epochs.
    Args:
        validation_losses: List of validation accuracies (or losses)
        training_losses: List of training accuracies (or losses)
        aggregation: Aggregation method used (default: "mean")
    """
    plt.figure(figsize=(10, 6))
    
    # Create figure with two y-axes
    fig, ax1 = plt.subplots(figsize=(10, 6))
    ax2 = ax1.twinx()
    
    # Plot training loss on the first y-axis
    epochs = range(1, len(training_losses) + 1)
    line1 = ax1.plot(epochs, training_losses, 'orchid', label=f'{graph1_label}')
    ax1.set_xlabel(x_label)
    ax1.set_ylabel(f'{graph1_label}', color='orchid')
    ax1.tick_params(axis='y', labelcolor='orchid')
    
    # Plot validation accuracy on the second y-axis
    line2 = ax2.plot(epochs, validation_losses, 'cornflowerblue', label=f'{graph2_label}')
    ax2.set_ylabel(f'{graph2_label}', color='cornflowerblue')
    ax2.tick_params(axis='y', labelcolor='cornflowerblue')
    
    # Add title and grid
    if not title:
        title = f'Training Accuracy and Validation Accuracy Over Time'
    plt.title(title)

    ax1.grid(True)
    
    # Add legend
    lines = line1 + line2
    labels = [l.get_label() for l in lines]
    ax1.legend(lines, labels, loc='upper right')
    
    plt.tight_layout()
    if save:
        fig_name = f"images/Q1/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# %% [markdown]
# ### Provided GCN Code

# %%
#Provided GCN Implementation
class GCNLayer(nn.Module):
    """
    A single layer of a Graph Convolutional Network (GCN).
    """
    def __init__(self, input_dim, output_dim, use_nonlinearity=True):
        super(GCNLayer, self).__init__()
        self.use_nonlinearity = use_nonlinearity
        self.Omega = nn.Parameter(torch.randn(input_dim, output_dim) * torch.sqrt(torch.tensor(2.0) / (input_dim + output_dim)))
        self.beta = nn.Parameter(torch.zeros(output_dim))

    def forward(self, H_k, A_normalized):
        agg = torch.matmul(A_normalized, H_k) # local agg
        H_k_next = torch.matmul(agg, self.Omega) + self.beta
        return F.relu(H_k_next) if self.use_nonlinearity else H_k_next

class GraphNeuralNetwork(nn.Module):
    """
    A simple Graph Neural Network model using two layers of Graph Convolutional Network (GCN)
    for binary classification. The sigmoid activation is applied in the output layer only if
    use_nonlinearity is set to True.
    """
    def __init__(self, input_dim, hidden_dim):
        super(GraphNeuralNetwork, self).__init__()

        # Define GCN layers
        self.gcn1 = GCNLayer(input_dim, hidden_dim, True)
        self.gcn2 = GCNLayer(hidden_dim, 1, False)

    def forward(self, A, X, **kwargs):
        # Pass through GCN layers
        H1 = self.gcn1(X, A)
        H2 = self.gcn2(H1, A)  # Output shape: (num_nodes, 1)

        output = torch.sigmoid(H2)  # Sigmoid activation per node
        if torch.isnan(output).any():
            output = torch.where(torch.isnan(output), torch.zeros_like(output), output)

        if kwargs.get("return_embeddings", None):
            return output, (H1, H2)
        else:
            return output

# %% [markdown]
# ### Helper functions for training GCN on a graph

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torch.nn.functional import binary_cross_entropy
from sklearn.metrics import accuracy_score, classification_report,precision_recall_fscore_support

def train_model(
    model,
    G_train,
    G_val,
    num_epochs=10,
    lr=0.0001,
    verbose=True,
    **kwargs,
):
    """
    Train the model, validate every 'validate_every' epochs, and pick the 
    checkpoint with best validation accuracy.

    Parameters:
    -----------
    model : torch.nn.Module
        The PyTorch model to train.
    G_train  = (X_train,A_train,y_train) : input
        the Graph 1
    Y_train = (X_val,A_val,y_val)
        the Graph 2
    num_epochs : int
        Number of training epochs.
    lr : float
        Learning rate for the optimizer.
    verbose: bool
        whether to display the loss, f1 and val_f1


    Returns:
    --------
    loss_history : list
        The training loss history across epochs.
    f1_train_history : list
        train F1s during training
    f1_val_history : list
        val F1s during training
    """
    X_train, A_train, y_train = G_train
    X_val, A_val, y_val = G_val

    model.train()
    optimizer = optim.AdamW(model.parameters(), lr=lr)
    loss_history = []
    train_f1_history = []
    validation_f1_history = []

    for epoch in range(num_epochs):
        # A single Epoch training.
        # TRAINING
        model.train()
        optimizer.zero_grad()
        if kwargs.get("return_embeddings", None):
            out, embeddings = model(A_train, X_train, **kwargs)
        else:
            out = model(A_train, X_train, **kwargs)
        out = out.squeeze(-1)  # shape: (N,) if needed
        y_float = y_train.float()  # for BCE

        # Compute training loss
        loss = binary_cross_entropy(out, y_float)
        loss.backward()

        # torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        # Record training loss
        loss_value = loss.item()
        
        # EVALUATION
        loss_history.append(loss_value)
        train_prec, train_rec, train_f1, _ = evaluate_model(model, X_train, A_train, y_train)
        val_prec, val_rec, val_f1, _ = evaluate_model(model,  X_val, A_val, y_val)

        train_f1_history.append(train_f1)
        validation_f1_history.append(val_f1)                     
        # Evaluating the model
        if verbose:
            print(f"Epoch {epoch+1}, Training Loss: {loss_value}, Train F1: {train_f1:.4f}, Validation F1: {val_f1:.4f}")
            
    if kwargs.get("return_embeddings", None):
        return loss_history, train_f1_history, validation_f1_history, embeddings
    else:
        return loss_history, train_f1_history, validation_f1_history


@torch.no_grad()
def evaluate_model(model, X,A,y, **kwargs):
    """
    Runs forward pass, calculates binary predictions (threshold=0.5),
    and returns the accuracy score.
    """
    model.eval()
    if kwargs.get("return_embeddings", None):
        out,_ = model(A,X,**kwargs)  # shape: (N, 1)
    else:
        out = model(A,X,**kwargs)  # shape: (N, 1)
    out = out.squeeze(-1)  # shape: (N,)
    preds = (out >= 0.5).long()

    y_true = y.cpu().numpy()
    y_pred = preds.cpu().numpy()

    return precision_recall_fscore_support(y_true, y_pred, average="micro")

# %% [markdown]
# ### Q3.2.a - Implementation of Layered GCN
#
#
# • Implement a GCN where layers can be passed as input parameter and that can return all
# embedding layers. (If you will not be able to do so, to get results implement one class per
# layer).
#
# • Train the GCN on G1 and G2 independently. Plot your results. (Note: you don’t need to
# get a high performance at this stage, just make sure it trains).

# %%
# SOLUTION Q3.2.a
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

class GCNLayer(nn.Module):
    """
    A single layer of a Graph Convolutional Network (GCN).
    """
    def __init__(self, input_dim, output_dim, use_nonlinearity=True):
        super(GCNLayer, self).__init__()
        self.use_nonlinearity = use_nonlinearity
        self.Omega = nn.Parameter(torch.randn(input_dim, output_dim) * torch.sqrt(torch.tensor(2.0) / (input_dim + output_dim)))
        self.beta = nn.Parameter(torch.zeros(output_dim))

    def forward(self, H_k, A_normalized):
        agg = torch.matmul(A_normalized, H_k) # local agg
        H_k_next = torch.matmul(agg, self.Omega) + self.beta
        return F.relu(H_k_next) if self.use_nonlinearity else H_k_next

# Adapted GCN Implementation
class LayeredGraphNeuralNetwork(nn.Module):
    """
    A simple Graph Neural Network model using two layers of Graph Convolutional Network (GCN)
    for binary classification. The sigmoid activation is applied in the output layer only if
    use_nonlinearity is set to True.
    """
    def __init__(self, input_dim, hidden_dim, layers=[]):
        super(LayeredGraphNeuralNetwork, self).__init__()   
        # Define GCN layers
        self.layers = nn.ModuleList()
        if len(layers) > 0:
            for layer in layers:
                self.layers.append(layer)
        else:
            # Default to 2 basic GCN layers
            self.layers.append(GCNLayer(input_dim, hidden_dim, True))
            self.layers.append(GCNLayer(hidden_dim, 1, False))


    def forward(self, A, X, **kwargs):
        # Apply self-connections and normalize adjacency matrix
        A = A + torch.eye(A.size(0)) # to get A_tilde
        A_normalized = symmetric_normalize(A)
        # Pass through all GCN layers
        H_k = X
        graph_embeddings = []
        for layer in self.layers:
            H_k = layer(H_k, A_normalized)
            graph_embeddings.append(H_k)

        graph_output = torch.sigmoid(H_k)

        if torch.isnan(graph_output).any():
            graph_output = torch.where(torch.isnan(graph_output), torch.zeros_like(graph_output), graph_output)

        if kwargs.get("return_embeddings", None):
            return graph_output, graph_embeddings
        else:
            return graph_output

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Code to run the training and evaluation of the model with different number of layers.
#
# Adapt it as needed.

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

# Initialising the model
input_dim = 10
hidden_dim = 8
layers = [GCNLayer(input_dim, hidden_dim, True), 
          GCNLayer(hidden_dim, hidden_dim, True), 
          GCNLayer(hidden_dim, hidden_dim, True), 
          GCNLayer(hidden_dim, 1, False)]
model = LayeredGraphNeuralNetwork(input_dim, hidden_dim, layers=layers) 
print(model)

losses, train_f1, val_f1, last_embeddings = train_model(
    model,
    G1_train,
    G1_eval,
    num_epochs=200,
    lr=0.0005,
    verbose=True,
    return_embeddings=True
)
plot_training_and_validation(losses, val_f1)
print(len(last_embeddings))
# Out:
# LayeredGraphNeuralNetwork(
#   (layers): ModuleList(
#     (0-3): 4 x GCNLayer()
#   )
# )
# Epoch 1, Training Loss: 0.7882834672927856, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 2, Training Loss: 0.7858787775039673, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 3, Training Loss: 0.7834911346435547, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 4, Training Loss: 0.781107485294342, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 5, Training Loss: 0.7787384986877441, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 6, Training Loss: 0.7763832211494446, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 7, Training Loss: 0.7740494012832642, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 8, Training Loss: 0.7717340588569641, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 9, Training Loss: 0.7694141268730164, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 10, Training Loss: 0.7670972347259521, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 11, Training Loss: 0.7647866010665894, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 12, Training Loss: 0.7624739408493042, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 13, Training Loss: 0.760157585144043, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 14, Training Loss: 0.757846474647522, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 15, Training Loss: 0.7555569410324097, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 16, Training Loss: 0.7532538175582886, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 17, Training Loss: 0.7509379386901855, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 18, Training Loss: 0.7486110925674438, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 19, Training Loss: 0.7462522983551025, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 20, Training Loss: 0.7439068555831909, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 21, Training Loss: 0.7415477633476257, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 22, Training Loss: 0.7391835451126099, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 23, Training Loss: 0.736848771572113, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 24, Training Loss: 0.7345531582832336, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 25, Training Loss: 0.7322651743888855, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 26, Training Loss: 0.72995525598526, Train F1: 0.4625, Validation F1: 0.5000
# Epoch
Train F1: 0.8500, Validation F1: 0.7667
# Epoch 145, Training Loss: 0.5692743062973022, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 146, Training Loss: 0.5686222910881042, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 147, Training Loss: 0.5679795145988464, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 148, Training Loss: 0.5673403739929199, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 149, Training Loss: 0.5667047500610352, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 150, Training Loss: 0.5660718083381653, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 151, Training Loss: 0.5654431581497192, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 152, Training Loss: 0.5648219585418701, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 153, Training Loss: 0.5642018914222717, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 154, Training Loss: 0.5635852217674255, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 155, Training Loss: 0.5629714727401733, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 156, Training Loss: 0.5623610019683838, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 157, Training Loss: 0.5617557764053345, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 158, Training Loss: 0.5611559152603149, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 159, Training Loss: 0.560560405254364, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 160, Training Loss: 0.5599724054336548, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 161, Training Loss: 0.5593841671943665, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 162, Training Loss: 0.558802604675293, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 163, Training Loss: 0.5582242012023926, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 164, Training Loss: 0.5576475262641907, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 165, Training Loss: 0.5570723414421082, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 166, Training Loss: 0.5564965009689331, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 167, Training Loss: 0.5559204816818237, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 168, Training Loss: 0.5553456544876099, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 169, Training Loss: 0.554775595664978, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 170, Training Loss: 0.5542041063308716, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 171, Training Loss: 0.5536333918571472, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 172, Training Loss: 0.5530637502670288, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 173, Training Loss: 0.5524947643280029, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 174, Training Loss: 0.5519261360168457, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 175, Training Loss: 0.5513531565666199, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 176, Training Loss: 0.5507798194885254, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 177, Training Loss: 0.5502102375030518, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 178, Training Loss: 0.5496411323547363, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 179, Training Loss: 0.5490714907646179, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 180, Training Loss: 0.5485017895698547, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 181, Training Loss: 0.5479320883750916, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 182, Training Loss: 0.547361433506012, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 183, Training Loss: 0.5467883348464966, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 184, Training Loss: 0.5462111234664917, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 185, Training Loss: 0.5456349849700928, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 186, Training Loss: 0.5450516939163208, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 187, Training Loss: 0.5444666147232056, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 188, Training Loss: 0.5438857078552246, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 189, Training Loss: 0.5433061718940735, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 190, Training Loss: 0.5427266955375671, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 191, Training Loss: 0.5421460866928101, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 192, Training Loss: 0.5415646433830261, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 193, Training Loss: 0.5409765839576721, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 194, Training Loss: 0.5403851270675659, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 195, Training Loss: 0.5397918820381165, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 196, Training Loss: 0.5391970872879028, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 197, Training Loss: 0.5386015176773071, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 198, Training Loss: 0.5380045175552368, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 199, Training Loss: 0.5374061465263367, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 200, Training Loss: 0.53680819272995, Train F1: 0.8500, Validation F1: 0.7667
# 4

# %% [markdown]
# ### Q3.2.b - Plotting of t-SNE Embeddings for Graph Neural Networks
#
# • Use t-SNE to visualize the node embeddings for the final layer of the GCN for each graph
# for both training and evaluation data, use the labels as class labels for the tsne plot.

# %%
# SOLUTION Q3.5.b
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  
from sklearn.manifold import TSNE

def plot_tsne(embeddings, labels=None, layer_to_plot=-1, colors=['cornflowerblue', 'orchid'], save=False, plot_name=""):
    """
    embeddings (list):
        list of embeddings (layer 2, ..., layer N)
        NOTE: for num_layer = 1 there is no embedding (as it is just the input)
    
    labels (list):
        list of labels
    
    layer_to_plot (int):
        which layer to plot (default -1, i.e. the last layer)
    """
    emb_to_plot = embeddings[layer_to_plot].detach().numpy()
    embedding_tsne = TSNE(n_components=1, perplexity = 5).fit_transform(emb_to_plot)

    fig, ax = plt.subplots(figsize=(6, 6))
    x = np.arange(len(embedding_tsne))
    for node_class in np.unique(labels):
        label_node_idx = np.where(labels == node_class)
        ax.scatter(x[label_node_idx], embedding_tsne[label_node_idx], label=f'Class {node_class}', color=colors[node_class], alpha=0.7, s=150)
    ax.legend()

    title = f"TSNE plot of embeddings at layer {layer_to_plot+1}"
    if layer_to_plot == -1 or layer_to_plot == len(embeddings)-1:
        title += ' (last layer)'
    ax.set_title(title)
    if save:
        fig_name = f"images/Q3/{plot_name}.pdf"
        plt.savefig(fig_name, format="pdf")
    plt.show()

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Plotting the t-SNE embeddings
#
# Adapt as needed.

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

# Initialising the model
input_dim = 10
hidden_dim = 8
layers = [GCNLayer(input_dim, hidden_dim, True), 
          GCNLayer(hidden_dim, hidden_dim, True), 
          GCNLayer(hidden_dim, hidden_dim, True), 
          GCNLayer(hidden_dim, 1, False)]
model = LayeredGraphNeuralNetwork(input_dim, hidden_dim, layers=layers)
print(model)

losses, train_f1, val_f1, last_embeddings = train_model(
    model,
    G1_train,
    G1_eval,
    num_epochs=200,
    lr=0.0005,
    verbose=True,
    return_embeddings=True # NOTE we added this parameter
)
plot_training_and_validation(losses, val_f1)

X,A,y = G1_train
print(len(last_embeddings))
for i in range(1, len(last_embeddings)): # Plot all layers
    plot_tsne(last_embeddings, y, i, save=True, plot_name=f"tSNE_layer_{str(i+1)}")
# Out:
# LayeredGraphNeuralNetwork(
#   (layers): ModuleList(
#     (0-3): 4 x GCNLayer()
#   )
# )
# Epoch 1, Training Loss: 0.6928063631057739, Train F1: 0.6500, Validation F1: 0.2667
# Epoch 2, Training Loss: 0.6924911737442017, Train F1: 0.6500, Validation F1: 0.2667
# Epoch 3, Training Loss: 0.6922277808189392, Train F1: 0.6750, Validation F1: 0.3667
# Epoch 4, Training Loss: 0.6919721364974976, Train F1: 0.6500, Validation F1: 0.3667
# Epoch 5, Training Loss: 0.6917248964309692, Train F1: 0.6875, Validation F1: 0.4333
# Epoch 6, Training Loss: 0.6914845705032349, Train F1: 0.7375, Validation F1: 0.4333
# Epoch 7, Training Loss: 0.6912482380867004, Train F1: 0.7375, Validation F1: 0.4667
# Epoch 8, Training Loss: 0.6910229921340942, Train F1: 0.7375, Validation F1: 0.5000
# Epoch 9, Training Loss: 0.6908043026924133, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 10, Training Loss: 0.6906009316444397, Train F1: 0.7625, Validation F1: 0.5667
# Epoch 11, Training Loss: 0.690382719039917, Train F1: 0.7750, Validation F1: 0.6333
# Epoch 12, Training Loss: 0.6901525855064392, Train F1: 0.7750, Validation F1: 0.6667
# Epoch 13, Training Loss: 0.6899095177650452, Train F1: 0.7875, Validation F1: 0.6667
# Epoch 14, Training Loss: 0.6896620392799377, Train F1: 0.7875, Validation F1: 0.6667
# Epoch 15, Training Loss: 0.6894065141677856, Train F1: 0.7875, Validation F1: 0.6667
# Epoch 16, Training Loss: 0.6891388893127441, Train F1: 0.7875, Validation F1: 0.6667
# Epoch 17, Training Loss: 0.6888571381568909, Train F1: 0.7875, Validation F1: 0.6667
# Epoch 18, Training Loss: 0.6885742545127869, Train F1: 0.7875, Validation F1: 0.6667
# Epoch 19, Training Loss: 0.6882870197296143, Train F1: 0.7875, Validation F1: 0.6667
# Epoch 20, Training Loss: 0.6879721879959106, Train F1: 0.7875, Validation F1: 0.7333
# Epoch 21, Training Loss: 0.6876398324966431, Train F1: 0.8000, Validation F1: 0.7333
# Epoch 22, Training Loss: 0.6872963905334473, Train F1: 0.8000, Validation F1: 0.7333
# Epoch 23, Training Loss: 0.6869394183158875, Train F1: 0.8000, Validation F1: 0.7333
# Epoch 24, Training Loss: 0.686566174030304, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 25, Training Loss: 0.6861817836761475, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 26, Training Loss: 0.6857830286026001, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 27, Training Loss: 0.6853690147399902, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 28, Training Loss: 0.6849595308303833, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 29, Training Loss: 0.6845427751541138, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 30, Training Loss: 0.6841049194335938, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 31, Training Loss: 0.6836457848548889, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 32, Training Loss: 0.6831780672073364, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 33, Training Loss: 0.6826880574226379, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 34, Training Loss: 0.6821633577346802, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 35, Training Loss: 0.6816148161888123, Train F1: 0.8250, Validation F1: 0.7667
# Epoch
Train F1: 0.8375, Validation F1: 0.7333
# Epoch 193, Training Loss: 0.5251808166503906, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 194, Training Loss: 0.5240951180458069, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 195, Training Loss: 0.523013710975647, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 196, Training Loss: 0.5219380259513855, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 197, Training Loss: 0.5208662748336792, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 198, Training Loss: 0.519798994064331, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 199, Training Loss: 0.518736720085144, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 200, Training Loss: 0.5176787376403809, Train F1: 0.8375, Validation F1: 0.7333
# 4

# %% [markdown]
# ### Q3.2.c - Training the Model on Merged Graphs G = G1 ∪ G
#
# • Implement a GCN that trains on both graphs at once. Plot the training curve.
#
# • Compare the performance of G = G1 ∪ G2 against training on G1 and G2, respectively.
#
# • Plot TSNE plots.

# %%
# SOLUTION Q3.2.c
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

# Implement the training of G = {G1 U G2}

# In the end return a single function:
def train_G1UG2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True, return_embeddings=True):
    """"""
    # Initialising the model
    input_dim = 10
    hidden_dim = 8

    G_train = G1_train[0] + G2_train[0], G1_train[1] + G2_train[1], G1_train[2] + G2_train[2]
    G_eval = G1_eval[0] + G2_eval[0], G1_eval[1] + G2_eval[1], G1_eval[2] + G2_eval[2]

    model = LayeredGraphNeuralNetwork(input_dim, hidden_dim)
    print(model)

    # losses_G1, train_G1_f1, val_G1_f1, last_embedding_G1 = train_model(
    losses, train_f1, val_f1, last_embeddings = train_model(
        model,
        G_train,
        G_eval,
        num_epochs=num_epochs,
        lr=lr,
        verbose=verbose,
        return_embeddings=return_embeddings
    )
    # model = LayeredGraphNeuralNetwork(input_dim, hidden_dim, layers=last_embedding_G1)
    # losses_G2, train_G2_f1, val_G2_f1, last_embedding_G2 = train_model(
    #     model,
    #     G2_train,
    #     G2_eval,
    #     num_epochs=num_epochs,
    #     lr=lr,
    #     verbose=verbose,
    #     return_embeddings=return_embeddings
    # )
    # losses = losses_G1 + losses_G2
    # train_f1 = train_G1_f1 + train_G2_f1
    # val_f1 = val_G1_f1 + val_G2_f1
    # last_embeddings = last_embedding_G1 + last_embedding_G2
    if return_embeddings:
        return losses, train_f1, val_f1, last_embeddings
    return losses, train_f1, val_f1

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Running the evaluation.

# %%
G1_train[0].shape, G2_train[0].shape, torch.stack(G1_train[0],G2_train[0], dim=0).shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[411], line 1
# ----> 1 G1_train[0].shape, G2_train[0].shape, torch.stack(G1_train[0],G2_train[0], dim=0).shape
#
# TypeError: stack(): argument 'tensors' (position 1) must be tuple of Tensors, not Tensor

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

losses, train_f1, val_f1, last_embeddings = train_G1UG2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True, return_embeddings=True)

plot_training_and_validation(losses, val_f1)
for i in range(1, len(last_embeddings)): # Plot all layers
    plot_tsne(last_embeddings, y, i, save=False, plot_name=f"tSNE_layer_{str(i+1)}")
# Out:
# LayeredGraphNeuralNetwork(
#   (layers): ModuleList(
#     (0-1): 2 x GCNLayer()
#   )
# )
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[407], line 8
#       5 G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
#       6 G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
# ----> 8 losses, train_f1, val_f1, last_embeddings = train_G1UG2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True, return_embeddings=True)
#      10 plot_training_and_validation(losses, val_f1)
#      11 for i in range(1, len(last_embeddings)): # Plot all layers
#
# Cell In[406], line 22, in train_G1UG2(G1_train, G1_eval, G2_train, G2_eval, num_epochs, lr, verbose, return_embeddings)
#      19 print(model)
#      21 # losses_G1, train_G1_f1, val_G1_f1, last_embedding_G1 = train_model(
# ---> 22 losses, train_f1, val_f1, last_embeddings = train_model(
#      23     model,
#      24     G_train,
#      25     G_eval,
#      26     num_epochs=num_epochs,
#      27     lr=lr,
#      28     verbose=verbose,
#      29     return_embeddings=return_embeddings
#      30 )
#      31 # model = LayeredGraphNeuralNetwork(input_dim, hidden_dim, layers=last_embedding_G1)
#      32 # losses_G2, train_G2_f1, val_G2_f1, last_embedding_G2 = train_model(
#      33 #     model,
#    (...)
#      43 # val_f1 = val_G1_f1 + val_G2_f1
#      44 # last_embeddings = last_embedding_G1 + last_embedding_G2
#      45 if return_embeddings:
#
# Cell In[313], line 67, in train_model(model, G_train, G_val, num_epochs, lr, verbose, **kwargs)
#      64 y_float = y_train.float()  # for BCE
#      66 # Compute training loss
# ---> 67 loss = binary_cross_entropy(out, y_float)
#      68 loss.backward()
#      70 # torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/functional.py:3554, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3551     new_size = _infer_size(target.size(), weight.size())
#    3552     weight = weight.expand(new_size)
# -> 3554 return torch._C._nn.binary_cross_entropy(input, target, weight, reduction_enum)
#
# RuntimeError: all elements of target should be between 0 and 1

# %% [markdown]
# ### Q3.2.d Implement & discuss what you observe.
#
# • Compare training results, embeddings, and overall observations between independent and
# merged training.
#
# • Formulate a hypothesis explaining your observations.
#
# • Discuss different implementation options for training on both graphs, including your choice.
# (e.g. what model modifications are possible; what training modifications are possible?)
#
# • Provide relevant plots and tables where appropriate.
#
# • Bonus: Implement a modification (or alternative approach) for training on G1 ∪ G2 and
# compare outcomes.

# %%
# SOLUTION Q3.2.d
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

# Implement the training of G = {G1 U G2}

# In the end return a single function:
def train_G1UG2_v2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True):
    """"""
    # INSERT necessary things
    return losses, train_f1, val_f1

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Runnning the evaluation.
#
# Note: It is optional to run this particular evaluation. You can modify it as needed.

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

losses, train_f1, val_f1 = train_G1UG2_v2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True)

plot_training_and_validation(losses, val_f1)

# %% [markdown]
# ## 3.3 Topological changes to improve training

# %% [markdown]
# ### Q3.3.a - Plot the Ricci Curvature for each edge.
#
# • Plot a barplot of the the Ricci curvature per edge, where the x-axis are the edges and y-axis
# is the ricci curvature.

# %%
# SOLUTION Q3.3.a
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  


# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label


# Plot curvature against edges
from graph_ricci_curvature import GraphRicciCurvature 

# plot_ricci_per_edge()


# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Q3.3.b Investigate the extreme case topologies.
#
# • How would you modify a topology so that the graph structure is ignored, making the GNN
# behave like an MLP?
#
# • What would an ideal graph structure be for optimal training and testing if labels were
# available (both during training and testing)?
#
# • What are you observations? Analyze the scores and what does it mean about the dataset?
#
# • Provide relevant plots and results.

# %%
# SOLUTION Q3.3.b
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def augment_graph_gold_labels(G):
    """Augment graph to return A that would be 'perfect'"""
    X,A,y = G
    return X,A,y

def augment_graph_no_effect(G):
    """Modify graph to return A that has no 'effect'"""
    X,A,y = G
    return X,A,y

    
def improved_training(
        G_train,
        G_eval,
        model_params,
        num_epochs=200,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = {},
    ):
    """
    How can you improve the topologies to train better.
    """
    if change_topology_params["augmentation_strategy"] == "no_effect":
        augmentation_function = augment_graph_no_effect
    elif change_topology_params["augmentation_strategy"] == "gold":
        augmentation_function = augment_graph_gold_labels
    else:
        raise NotImplementedError("This augmentation setting is not implemented.")

    G_train = augmentation_function(G_train)
    G_train = G_train[0],symmetric_normalize(G_train[1]),G_train[2]

    G_eval = augmentation_function(G_eval)
    G_eval = G_eval[0],symmetric_normalize(G_eval[1]),G_eval[2]

    # Initialising the model
    model = LayeredGraphNeuralNetwork(**model_params)
    print(model)

    losses, train_f1, val_f1, last_embeddings = train_model(
        model,
        G_train,
        G_eval,
        num_epochs=num_epochs,
        lr=lr,
        verbose=verbose,
        return_embeddings = True
    )
    return losses, train_f1, val_f1, last_embeddings

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Code to run improvement
# Note: run it a few times to see what performance can be reached on the eval dataset.

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

model_params = {    
    "input_dim":10, 
    "hidden_dim":8,
    "num_layers":4,
}

change_topology_params = {
    "augmentation_strategy":"no_effect",
    "normalise" : False,
}

# change_topology_params = {
#     "augmentation_strategy":"gold",
#     "normalise" : True,

# }

losses, train_f1, val_f1, last_embeddings = improved_training(
    G2_train,
    G2_eval,
    model_params=model_params,
    num_epochs=250,
    lr=0.0005,
    verbose=True,
    return_embeddings = True,
    change_topology_params = change_topology_params #change as needed
)
plot_training_and_validation(losses, val_f1)

X,A,y = G1_train
print(len(last_embeddings))
plot_tsne(last_embeddings, y)

# %% [markdown]
# ### Q3.3.C Improving Graph Topology for Better Learning
#
# • Implement two graph modifications.
#
# • Describe your modifications.
#
# • What motivated your implementation?
#
# • If it helped give a hypothesis on why you think that is? If it did not give a hypothesis why
# you think it did not help.
#
# • Provide relevant plots and results

# %%
# SOLUTION Q3.3.c
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def augment_graph(G):
    """Augments the graph."""
    X,A,y = G

    return X,A,y
    
def improved_training(
        G_train,
        G_eval,
        model_params,
        num_epochs=200,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = {},
    ):
    """
    How can you improve the topologies to train better.
    """

    G_train = augment_graph(G_train)
    G_train = G_train[0],symmetric_normalize(G_train[1]),G_train[2]

    G_eval = augment_graph(G_eval)
    G_eval = G_eval[0],symmetric_normalize(G_eval[1]),G_eval[2]

    # Initialising the model
    model = LayeredGraphNeuralNetwork(**model_params)
    print(model)

    losses, train_f1, val_f1, last_embeddings = train_model(
        model,
        G_train,
        G_eval,
        num_epochs=num_epochs,
        lr=lr,
        verbose=verbose,
        return_embeddings = True
    )
    return losses, train_f1, val_f1, last_embeddings

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Code to run improvement

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label


model_params = {    
    "input_dim":10, 
    "hidden_dim":8,
    "num_layers":4,
}

change_topology_params = {
    "augmentation_strategy":"eval",
}

losses, train_f1, val_f1, last_embeddings = improved_training(
    G2_train,
    G2_eval,
    model_params=model_params,
    num_epochs=200,
    lr=0.0005,
    verbose=True,
    return_embeddings = True,
    change_topology_params = change_topology_params #change as needed
)
plot_training_and_validation(losses, val_f1)

X,A,y = G1_train
print(len(last_embeddings))
plot_tsne(last_embeddings, y)
